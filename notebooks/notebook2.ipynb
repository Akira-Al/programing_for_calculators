# %%
import sys
sys.path.append("../")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from janome.tokenizer import Tokenizer

# %%
from auto_polar.lib.predict_polarity import PolarEstimator, Dict1, Dict2
from auto_polar.lib import load_dictionary

# %%
dict1_df = pd.read_csv("../data/dictionary1.txt", sep="\t", header=None)
dict1_df.columns = ["word", "score", "description"]
dict1_df
# Out:
#        word score        description
# 0      ２，３日     e     〜である・になる（状態）客観
# 1       10%     e     〜である・になる（状態）客観
# 2      100%     e     〜である・になる（状態）客観
# 3       25%     e     〜である・になる（状態）客観
# 4       80%     e     〜である・になる（状態）客観
# ...     ...   ...                ...
# 13309     魏     e           〜に行く（場所）
# 13310  魑魅魍魎     n     〜である・になる（状態）客観
# 13311     鮑     e     〜である・になる（状態）客観
# 13312    鹹味     e  〜である・になる（評価・感情）主観
# 13313    麒麟     e     〜である・になる（状態）客観
#
# [13314 rows x 3 columns]

# %%
dict1_df["score"].value_counts()
# Out:
# score
# n       4958
# e       4954
# p       3352
# ?p?n      35
# ?e         4
# a          4
# o          3
# ?p         2
# ?p?e       1
# 　          1
# Name: count, dtype: int64

# %%
with open("../data/data.txt", "r", encoding="UTF-8") as f:
    inputs = f.readlines()

# %%
for token in Tokenizer().tokenize(inputs[1]):
    print(token)
    print(token.surface)
    print(token.base_form)
# Out:
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# 友達
# 友達
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# と
# と
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# 映画
# 映画
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# を
# を
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# 見
# 見る
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# に
# に
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# 行っ
# 行く
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# た
# た
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# けど
# けど
# 、	記号,読点,*,*,*,*,、,、,、
# 、
# 、
# 感動	名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー
# 感動
# 感動
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# し
# する
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# て
# て
# 泣い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,泣く,ナイ,ナイ
# 泣い
# 泣く
# ちゃっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,ちゃう,チャッ,チャッ
# ちゃっ
# ちゃう
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# た
# た
# 。	記号,句点,*,*,*,*,。,。,。
# 。
# 。

# %%
dict1 = load_dictionary.load_dict1("../data/dictionary1.txt")
dict2 = load_dictionary.load_dict2("../data/dictionary2.txt")

# %%
polar_estimator = PolarEstimator(Dict1(dict1), Dict2(dict2))

# %%
polar_estimator.estimate_v1(inputs[0], verbose=True)
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0

# %%
polar_estimator.estimate_v2(inputs[0], verbose=True)
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# [dict2]  ['落ち込む'] -1
# [dict2]  ['晴れる'] 1
# 0

# %%
for text in inputs:
    print(polar_estimator.estimate_v1(text, verbose=True))
    print()
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 友達と映画を見に行ったけど、感動して泣いちゃった。
#
# [dict1]  友達 1
# [dict1]  感動 1
# 2
#
# text: 新しい仕事が始まって緊張するけど、頑張りたい。
#
# [dict1]  仕事 0
# [dict1]  緊張 -1
# -1
#
# text: 美味しいケーキを食べて、幸せな気持ちになった。
#
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 2
#
# text: ペットが病気になって心配でたまらない。早く元気になって。
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# text: 家族と一緒に過ごす時間がとても楽しかった。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# 1
#
# text: 仕事でミスをして上司に叱られてしまった。反省しないと。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict1]  反省 0
# -1
#
# text: 旅行の計画を立てているときが一番ワクワクする。
#
# [dict1]  旅行 1
# [dict1]  一番 1
# 2
#
# text: 久しぶりに会った友達と話して、元気が出た。
#
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# 2
#
# text: 電車が遅れてイライラするけど、仕方がない。
#
# 0
#
# text: 新しい趣味を見つけて、毎日が楽しい。
#
# [dict1]  趣味 0
# 0
#
# text: 彼氏とのデートで素敵なレストランに行って幸せ。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  幸せ 1
# 3
#
# text: 今日も一日がんばった。自分を褒めたい気分。
#
# [dict1]  自分 0
# [dict1]  気分 0
# 0
#
# text: 雨の日はどうしても気分が沈んでしまう。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 大好きな音楽を聴くと気分が明るくなる。
#
# [dict1]  大好き 1
# [dict1]  気分 0
# 1
#
# text: 試験の結果が悪くて、落ち込んでしまった。
#
# [dict1]  試験 -1
# -1
#
# text: 彼女からのサプライズプレゼントに感動した。
#
# [dict1]  感動 1
# 1
#
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
#
# [dict1]  久しぶり 0
# [dict1]  休み 0
# 0
#
# text: 仕事が忙しくてストレスが溜まっている。
#
# [dict1]  仕事 0
# [dict1]  ストレス -1
# -1
#
# text: 友達と喧嘩してしまって、悲しい気持ちになった。
#
# [dict1]  友達 1
# [dict1]  喧嘩 -1
# [dict1]  気持ち 1
# 1
#
# text: 新しい洋服を買って、気分が上がった。
#
# [dict1]  気分 0
# 0
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# 2
#
# text: 今日は特に何もない一日だったけど、それも悪くない。
#
# 0
#
# text: 親友と久しぶりに再会して、楽しい時間を過ごした。
#
# [dict1]  親友 1
# [dict1]  久しぶり 0
# [dict1]  再会 0
# [dict1]  時間 0
# 1
#
# text: 好きなドラマの新シーズンが始まって嬉しい。
#
# [dict1]  好き 1
# [dict1]  新 0
# 1
#
# text: 失恋してからなかなか立ち直れない。
#
# [dict1]  失恋 -1
# -1
#
# text: 仕事のプレゼンがうまくいって、自信がついた。
#
# [dict1]  仕事 0
# [dict1]  自信 1
# 1
#
# text: 朝から体調が悪くて、一日中寝ていた。
#
# [dict1]  朝 0
# [dict1]  中 0
# 0
#
# text: 散歩中に見た夕日がとても綺麗だった。
#
# [dict1]  散歩 1
# [dict1]  中 0
# [dict1]  綺麗 1
# 2
#
# text: 新しいレシピを試してみたら、美味しくできた。
#
# 0
#
# text: 同僚に助けられて、感謝の気持ちでいっぱい。
#
# [dict1]  感謝 1
# [dict1]  気持ち 1
# [dict1]  いっぱい 0
# 2
#
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
#
# 0
#
# text: スポーツジムで体を動かして、スッキリした。
#
# [dict1]  スポーツ 0
# 0
#
# text: 雨上がりの虹を見て、心が洗われるようだった。
#
# 0
#
# text: 試合に勝って、チーム全員で喜んだ。
#
# 0
#
# text: 今日は誕生日で、たくさんのメッセージをもらった。
#
# [dict1]  誕生 1
# [dict1]  たくさん 0
# 1
#
# text: ミスをしてしまって、上司に怒られて落ち込んだ。
#
# [dict1]  ミス -1
# -1
#
# text: 久しぶりに母の手料理を食べて、懐かしい気分になった。
#
# [dict1]  久しぶり 0
# [dict1]  気分 0
# 0
#
# text: 面白い本を見つけて、読みふけってしまった。
#
# 0
#
# text: 友達の結婚式に参加して、幸せな気持ちになった。
#
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 3
#
# text: 風邪をひいてしまって、ずっと寝ている。
#
# [dict1]  風邪 -1
# -1
#
# text: 新しいゲームを始めて、ハマってしまった。
#
# [dict1]  ゲーム 0
# 0
#
# text: 猫が膝の上に乗ってきて、癒された。
#
# 0
#
# text: 長い一日が終わって、ほっと一息ついた。
#
# 0
#
# text: 昇進が決まって、とても嬉しい。
#
# [dict1]  昇進 1
# 1
#
# text: お風呂に入ってリラックスする時間が好き。
#
# [dict1]  リラックス 1
# [dict1]  時間 0
# [dict1]  好き 1
# 2
#
# text: 友達とカフェでおしゃべりして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# 1
#
# text: 自分の作品が認められて、嬉しい気持ちになった。
#
# [dict1]  自分 0
# [dict1]  気持ち 1
# 1
#
# text: 会議が長引いて疲れたけど、達成感がある。
#
# [dict1]  達成 1
# 1
#
# text: 彼女との旅行が楽しみで、待ちきれない。
#
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# 2
#
# text: 仕事が終わって家に帰ると、ホッとする。
#
# [dict1]  仕事 0
# 0
#
# text: 好きなバンドのライブに行って、最高の夜だった。
#
# [dict1]  好き 1
# [dict1]  最高 1
# 2
#
# text: 忙しい日々が続いていて、少し疲れている。
#
# 0
#
# text: 彼氏からのサプライズに驚いて、嬉しかった。
#
# 0
#
# text: 親友と大喧嘩してしまって、後悔している。
#
# [dict1]  親友 1
# [dict1]  喧嘩 -1
# [dict1]  後悔 -1
# -1
#
# text: 美味しいラーメンを食べて、幸せな気持ちになった。
#
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 2
#
# text: 風が強くて、外に出るのが億劫だった。
#
# 0
#
# text: 新しいプロジェクトが始まって、やる気満々。
#
# [dict1]  やる気 1
# 1
#
# text: 長時間の会議で疲れ果ててしまった。
#
# [dict1]  長時間 0
# 0
#
# text: 久しぶりに海に行って、リフレッシュできた。
#
# [dict1]  久しぶり 0
# [dict1]  リフレッシュ 1
# 1
#
# text: 試験勉強が大変で、ストレスが溜まっている。
#
# [dict1]  試験 -1
# [dict1]  大変 -1
# [dict1]  ストレス -1
# -3
#
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
#
# [dict1]  友達 1
# 1
#
# text: プレゼントをもらって、心が温まった。
#
# [dict1]  プレゼント 1
# 1
#
# text: 好きなアーティストのコンサートが楽しみ。
#
# [dict1]  好き 1
# [dict1]  アーティスト 0
# [dict1]  楽しみ 1
# 2
#
# text: 雨の日は読書に限ると、改めて感じた。
#
# [dict1]  雨 0
# 0
#
# text: 体調が良くなくて、会社を休んだ。
#
# 0
#
# text: 新しい料理に挑戦して、上手くできた。
#
# [dict1]  料理 0
# [dict1]  挑戦 0
# 0
#
# text: 映画館で見た映画がとても面白かった。
#
# 0
#
# text: 彼氏とケンカして、悲しい気持ちになった。
#
# [dict1]  ケンカ -1
# [dict1]  気持ち 1
# 0
#
# text: 友達とアウトドアに出かけて、楽しかった。
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# 1
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# 1
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# 2
#
# text: 雪が降っていて、外に出るのが楽しみ。
#
# [dict1]  雪 0
# [dict1]  楽しみ 1
# 1
#
# text: 新しいカフェを見つけて、友達と行ってみた。
#
# [dict1]  友達 1
# 1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# -1
#
# text: 好きなアニメの新作が出て、ワクワクしている。
#
# [dict1]  好き 1
# [dict1]  新作 0
# 1
#
# text: 体調が悪くて、早退した。
#
# [dict1]  早退 -1
# -1
#
# text: 友達と旅行に行って、最高の思い出ができた。
#
# [dict1]  友達 1
# [dict1]  旅行 1
# [dict1]  最高 1
# [dict1]  思い出 1
# 4
#
# text: 疲れているのに、寝付けない夜が続いている。
#
# 0
#
# text: 新しい靴を買って、ウキウキしている。
#
# 0
#
# text: 恋人との記念日を祝って、幸せな時間を過ごした。
#
# [dict1]  恋人 1
# [dict1]  記念 0
# [dict1]  幸せ 1
# [dict1]  時間 0
# 2
#
# text: 上司に褒められて、自信がついた。
#
# [dict1]  自信 1
# 1
#
# text: 雨の日の静けさが好きで、落ち着く。
#
# [dict1]  雨 0
# [dict1]  静けさ 1
# [dict1]  好き 1
# 2
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# 1
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: お風呂にゆっくり浸かって、リラックスした。
#
# [dict1]  リラックス 1
# 1
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# 0
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 大好きなカフェで、ゆっくり過ごす時間が幸せ。
#
# [dict1]  大好き 1
# [dict1]  時間 0
# [dict1]  幸せ 1
# 2
#
# text: 友達の誕生日を祝って、一緒に楽しんだ。
#
# [dict1]  友達 1
# [dict1]  誕生 1
# [dict1]  一緒 1
# 3
#
# text: 仕事が忙しくて、なかなか休めない。
#
# [dict1]  仕事 0
# 0
#
# text: 好きな映画を見て、リフレッシュできた。
#
# [dict1]  好き 1
# [dict1]  リフレッシュ 1
# 2
#
# text: 新しい趣味を見つけて、毎日が楽しい。
#
# [dict1]  趣味 0
# 0
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 雨が降っていて、外に出るのが憂鬱。
#
# [dict1]  雨 0
# [dict1]  憂鬱 -1
# -1
#
# text: 友達と一緒にいると、元気が出る。
#
# [dict1]  友達 1
# [dict1]  一緒 1
# [dict1]  元気 1
# 3
#
# text: 仕事でミスをして、上司に叱られた。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# -1
#
# text: 新しいレストランで、美味しい料理を楽しんだ。
#
# [dict1]  料理 0
# 0
#
# text: 体調が悪くて、一日中寝ていた。
#
# [dict1]  中 0
# 0
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# 1
#
# text: 彼氏からのサプライズに感動した。
#
# [dict1]  感動 1
# 1
#
# text: 忙しい日々が続いていて、少し疲れている。
#
# 0
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# 2
#
# text: 雨の日はどうしても気分が沈んでしまう。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 新しい仕事が始まって、緊張するけど頑張りたい。
#
# [dict1]  仕事 0
# [dict1]  緊張 -1
# -1
#
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
#
# [dict1]  友達 1
# 1
#
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
#
# 0
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: 体調が良くなくて、会社を休んだ。
#
# 0
#
# text: 好きな音楽を聴くと気分が明るくなる。
#
# [dict1]  好き 1
# [dict1]  気分 0
# 1
#
# text: 友達と映画を見に行ったけど、感動して泣いちゃった。
#
# [dict1]  友達 1
# [dict1]  感動 1
# 2
#
# text: 新しいプロジェクトが始まって、やる気満々。
#
# [dict1]  やる気 1
# 1
#
# text: 彼女との旅行が楽しみで、待ちきれない。
#
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# 2
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# 2
#
# text: 好きなドラマの新シーズンが始まって嬉しい。
#
# [dict1]  好き 1
# [dict1]  新 0
# 1
#
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
#
# [dict1]  久しぶり 0
# [dict1]  休み 0
# 0
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# 1
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# 0
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 仕事が忙しくてストレスが溜まっている。
#
# [dict1]  仕事 0
# [dict1]  ストレス -1
# -1
#
# text: ペットが病気になって心配でたまらない。早く元気になって。
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# -1
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 猫が膝の上に乗ってきて、癒された。
#
# 0
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# 1
#
# text: 友達とアウトドアに出かけて、楽しかった。
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# 1
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# 1
#
# text: 新しいレシピを試してみたら、美味しくできた。
#
# 0
#
# text: 久しぶりに会った友達と話して、元気が出た。
#
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# 2
#
# text: 昇進が決まって、とても嬉しい。
#
# [dict1]  昇進 1
# 1
#
# text: 仕事が終わって家に帰ると、ホッとする。
#
# [dict1]  仕事 0
# 0
#
# text: 映画館で見た映画がとても面白かった。
#
# 0
#
# text: 長時間の会議で疲れ果ててしまった。
#
# [dict1]  長時間 0
# 0
#
# text: 今日は誕生日で、たくさんのメッセージをもらった。
#
# [dict1]  誕生 1
# [dict1]  たくさん 0
# 1
#
# text: 旅行の計画を立てているときが一番ワクワクする。
#
# [dict1]  旅行 1
# [dict1]  一番 1
# 2
#
# text: 試合に勝って、チーム全員で喜んだ。
#
# 0
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# 2
#
# text: 今日は特に何もない一日だったけど、それも悪くない。
#
# 0
#
# text: 新しいゲームを始めて、ハマってしまった。
#
# [dict1]  ゲーム 0
# 0
#
# text: 友達の結婚式に参加して、幸せな気持ちになった。```
#
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 3

# %%
for text in inputs:
    print(polar_estimator.estimate_v2(text, verbose=True))
    print()
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# [dict2]  ['落ち込む'] -1
# [dict2]  ['晴れる'] 1
# 0
#
# text: 友達と映画を見に行ったけど、感動して泣いちゃった。
#
# [dict1]  友達 1
# [dict1]  感動 1
# 2
#
# text: 新しい仕事が始まって緊張するけど、頑張りたい。
#
# [dict1]  仕事 0
# [dict1]  緊張 -1
# [dict2]  ['頑張る'] 1
# 0
#
# text: 美味しいケーキを食べて、幸せな気持ちになった。
#
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [dict2]  ['美味しい'] 1
# 3
#
# text: ペットが病気になって心配でたまらない。早く元気になって。
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# text: 家族と一緒に過ごす時間がとても楽しかった。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 仕事でミスをして上司に叱られてしまった。反省しないと。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict1]  反省 0
# -1
#
# text: 旅行の計画を立てているときが一番ワクワクする。
#
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# 3
#
# text: 久しぶりに会った友達と話して、元気が出た。
#
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# 2
#
# text: 電車が遅れてイライラするけど、仕方がない。
#
# [dict2]  ['遅れる'] -1
# [dict2]  ['仕方', 'が', 'ない'] -1
# -2
#
# text: 新しい趣味を見つけて、毎日が楽しい。
#
# [dict1]  趣味 0
# [dict2]  ['楽しい'] 1
# 1
#
# text: 彼氏とのデートで素敵なレストランに行って幸せ。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  幸せ 1
# 3
#
# text: 今日も一日がんばった。自分を褒めたい気分。
#
# [dict1]  自分 0
# [dict1]  気分 0
# 0
#
# text: 雨の日はどうしても気分が沈んでしまう。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 大好きな音楽を聴くと気分が明るくなる。
#
# [dict1]  大好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# 2
#
# text: 試験の結果が悪くて、落ち込んでしまった。
#
# [dict1]  試験 -1
# [dict2]  ['悪い'] -1
# [dict2]  ['落ち込む'] -1
# -3
#
# text: 彼女からのサプライズプレゼントに感動した。
#
# [dict1]  感動 1
# 1
#
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
#
# [dict1]  久しぶり 0
# [dict1]  休み 0
# 0
#
# text: 仕事が忙しくてストレスが溜まっている。
#
# [dict1]  仕事 0
# [dict1]  ストレス -1
# [dict2]  ['忙しい'] -1
# -2
#
# text: 友達と喧嘩してしまって、悲しい気持ちになった。
#
# [dict1]  友達 1
# [dict1]  喧嘩 -1
# [dict1]  気持ち 1
# [dict2]  ['悲しい'] -1
# 0
#
# text: 新しい洋服を買って、気分が上がった。
#
# [dict1]  気分 0
# 0
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# 3
#
# text: 今日は特に何もない一日だったけど、それも悪くない。
#
# [dict2]  ['悪い'] -1
# 1
#
# text: 親友と久しぶりに再会して、楽しい時間を過ごした。
#
# [dict1]  親友 1
# [dict1]  久しぶり 0
# [dict1]  再会 0
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 好きなドラマの新シーズンが始まって嬉しい。
#
# [dict1]  好き 1
# [dict1]  新 0
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 失恋してからなかなか立ち直れない。
#
# [dict1]  失恋 -1
# -1
#
# text: 仕事のプレゼンがうまくいって、自信がついた。
#
# [dict1]  仕事 0
# [dict1]  自信 1
# [dict2]  ['うまい'] 1
# 2
#
# text: 朝から体調が悪くて、一日中寝ていた。
#
# [dict1]  朝 0
# [dict1]  中 0
# [dict2]  ['悪い'] -1
# -1
#
# text: 散歩中に見た夕日がとても綺麗だった。
#
# [dict1]  散歩 1
# [dict1]  中 0
# [dict1]  綺麗 1
# 2
#
# text: 新しいレシピを試してみたら、美味しくできた。
#
# [dict2]  ['美味しい'] 1
# 1
#
# text: 同僚に助けられて、感謝の気持ちでいっぱい。
#
# [dict1]  感謝 1
# [dict1]  気持ち 1
# [dict1]  いっぱい 0
# 2
#
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
#
# [dict2]  ['楽しい'] 1
# 1
#
# text: スポーツジムで体を動かして、スッキリした。
#
# [dict1]  スポーツ 0
# 0
#
# text: 雨上がりの虹を見て、心が洗われるようだった。
#
# 0
#
# text: 試合に勝って、チーム全員で喜んだ。
#
# [dict2]  ['勝つ'] 1
# [dict2]  ['喜ぶ'] 1
# 2
#
# text: 今日は誕生日で、たくさんのメッセージをもらった。
#
# [dict1]  誕生 1
# [dict1]  たくさん 0
# 1
#
# text: ミスをしてしまって、上司に怒られて落ち込んだ。
#
# [dict1]  ミス -1
# [dict2]  ['怒る'] -1
# [dict2]  ['落ち込む'] -1
# -3
#
# text: 久しぶりに母の手料理を食べて、懐かしい気分になった。
#
# [dict1]  久しぶり 0
# [dict1]  気分 0
# 0
#
# text: 面白い本を見つけて、読みふけってしまった。
#
# [dict2]  ['面白い'] 1
# 1
#
# text: 友達の結婚式に参加して、幸せな気持ちになった。
#
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 3
#
# text: 風邪をひいてしまって、ずっと寝ている。
#
# [dict1]  風邪 -1
# -1
#
# text: 新しいゲームを始めて、ハマってしまった。
#
# [dict1]  ゲーム 0
# 0
#
# text: 猫が膝の上に乗ってきて、癒された。
#
# [dict2]  ['癒す'] 1
# 1
#
# text: 長い一日が終わって、ほっと一息ついた。
#
# 0
#
# text: 昇進が決まって、とても嬉しい。
#
# [dict1]  昇進 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: お風呂に入ってリラックスする時間が好き。
#
# [dict1]  リラックス 1
# [dict1]  時間 0
# [dict1]  好き 1
# 2
#
# text: 友達とカフェでおしゃべりして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 自分の作品が認められて、嬉しい気持ちになった。
#
# [dict1]  自分 0
# [dict1]  気持ち 1
# [dict2]  ['認める'] 1
# [dict2]  ['嬉しい'] 1
# 3
#
# text: 会議が長引いて疲れたけど、達成感がある。
#
# [dict1]  達成 1
# [dict2]  ['疲れる'] -1
# 0
#
# text: 彼女との旅行が楽しみで、待ちきれない。
#
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# 2
#
# text: 仕事が終わって家に帰ると、ホッとする。
#
# [dict1]  仕事 0
# 0
#
# text: 好きなバンドのライブに行って、最高の夜だった。
#
# [dict1]  好き 1
# [dict1]  最高 1
# 2
#
# text: 忙しい日々が続いていて、少し疲れている。
#
# [dict2]  ['忙しい'] -1
# [dict2]  ['疲れる'] -1
# -2
#
# text: 彼氏からのサプライズに驚いて、嬉しかった。
#
# [dict2]  ['嬉しい'] 1
# 1
#
# text: 親友と大喧嘩してしまって、後悔している。
#
# [dict1]  親友 1
# [dict1]  喧嘩 -1
# [dict1]  後悔 -1
# -1
#
# text: 美味しいラーメンを食べて、幸せな気持ちになった。
#
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [dict2]  ['美味しい'] 1
# 3
#
# text: 風が強くて、外に出るのが億劫だった。
#
# 0
#
# text: 新しいプロジェクトが始まって、やる気満々。
#
# [dict1]  やる気 1
# 1
#
# text: 長時間の会議で疲れ果ててしまった。
#
# [dict1]  長時間 0
# [dict2]  ['疲れる'] -1
# -1
#
# text: 久しぶりに海に行って、リフレッシュできた。
#
# [dict1]  久しぶり 0
# [dict1]  リフレッシュ 1
# 1
#
# text: 試験勉強が大変で、ストレスが溜まっている。
#
# [dict1]  試験 -1
# [dict1]  大変 -1
# [dict1]  ストレス -1
# -3
#
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
#
# [dict1]  友達 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: プレゼントをもらって、心が温まった。
#
# [dict1]  プレゼント 1
# [dict2]  ['温まる'] 1
# 2
#
# text: 好きなアーティストのコンサートが楽しみ。
#
# [dict1]  好き 1
# [dict1]  アーティスト 0
# [dict1]  楽しみ 1
# 2
#
# text: 雨の日は読書に限ると、改めて感じた。
#
# [dict1]  雨 0
# 0
#
# text: 体調が良くなくて、会社を休んだ。
#
# [dict2]  ['良い'] 1
# -1
#
# text: 新しい料理に挑戦して、上手くできた。
#
# [dict1]  料理 0
# [dict1]  挑戦 0
# [dict2]  ['上手い'] 1
# 1
#
# text: 映画館で見た映画がとても面白かった。
#
# [dict2]  ['面白い'] 1
# 1
#
# text: 彼氏とケンカして、悲しい気持ちになった。
#
# [dict1]  ケンカ -1
# [dict1]  気持ち 1
# [dict2]  ['悲しい'] -1
# -1
#
# text: 友達とアウトドアに出かけて、楽しかった。
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# 2
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# 3
#
# text: 雪が降っていて、外に出るのが楽しみ。
#
# [dict1]  雪 0
# [dict1]  楽しみ 1
# 1
#
# text: 新しいカフェを見つけて、友達と行ってみた。
#
# [dict1]  友達 1
# 1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# -2
#
# text: 好きなアニメの新作が出て、ワクワクしている。
#
# [dict1]  好き 1
# [dict1]  新作 0
# [dict2]  ['わくわく'] 1
# 2
#
# text: 体調が悪くて、早退した。
#
# [dict1]  早退 -1
# [dict2]  ['悪い'] -1
# -2
#
# text: 友達と旅行に行って、最高の思い出ができた。
#
# [dict1]  友達 1
# [dict1]  旅行 1
# [dict1]  最高 1
# [dict1]  思い出 1
# 4
#
# text: 疲れているのに、寝付けない夜が続いている。
#
# [dict2]  ['疲れる'] -1
# -1
#
# text: 新しい靴を買って、ウキウキしている。
#
# [dict2]  ['うきうき'] 1
# 1
#
# text: 恋人との記念日を祝って、幸せな時間を過ごした。
#
# [dict1]  恋人 1
# [dict1]  記念 0
# [dict1]  幸せ 1
# [dict1]  時間 0
# 2
#
# text: 上司に褒められて、自信がついた。
#
# [dict1]  自信 1
# 1
#
# text: 雨の日の静けさが好きで、落ち着く。
#
# [dict1]  雨 0
# [dict1]  静けさ 1
# [dict1]  好き 1
# [dict2]  ['落ち着く'] 1
# 3
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# 2
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: お風呂にゆっくり浸かって、リラックスした。
#
# [dict1]  リラックス 1
# 1
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# -1
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 大好きなカフェで、ゆっくり過ごす時間が幸せ。
#
# [dict1]  大好き 1
# [dict1]  時間 0
# [dict1]  幸せ 1
# 2
#
# text: 友達の誕生日を祝って、一緒に楽しんだ。
#
# [dict1]  友達 1
# [dict1]  誕生 1
# [dict1]  一緒 1
# [dict2]  ['楽しむ'] 1
# 4
#
# text: 仕事が忙しくて、なかなか休めない。
#
# [dict1]  仕事 0
# [dict2]  ['忙しい'] -1
# -1
#
# text: 好きな映画を見て、リフレッシュできた。
#
# [dict1]  好き 1
# [dict1]  リフレッシュ 1
# 2
#
# text: 新しい趣味を見つけて、毎日が楽しい。
#
# [dict1]  趣味 0
# [dict2]  ['楽しい'] 1
# 1
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 雨が降っていて、外に出るのが憂鬱。
#
# [dict1]  雨 0
# [dict1]  憂鬱 -1
# -1
#
# text: 友達と一緒にいると、元気が出る。
#
# [dict1]  友達 1
# [dict1]  一緒 1
# [dict1]  元気 1
# 3
#
# text: 仕事でミスをして、上司に叱られた。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# -1
#
# text: 新しいレストランで、美味しい料理を楽しんだ。
#
# [dict1]  料理 0
# [dict2]  ['美味しい'] 1
# [dict2]  ['楽しむ'] 1
# 2
#
# text: 体調が悪くて、一日中寝ていた。
#
# [dict1]  中 0
# [dict2]  ['悪い'] -1
# -1
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 彼氏からのサプライズに感動した。
#
# [dict1]  感動 1
# 1
#
# text: 忙しい日々が続いていて、少し疲れている。
#
# [dict2]  ['忙しい'] -1
# [dict2]  ['疲れる'] -1
# -2
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# 3
#
# text: 雨の日はどうしても気分が沈んでしまう。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 新しい仕事が始まって、緊張するけど頑張りたい。
#
# [dict1]  仕事 0
# [dict1]  緊張 -1
# [dict2]  ['頑張る'] 1
# 0
#
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
#
# [dict1]  友達 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
#
# [dict2]  ['楽しい'] 1
# 1
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: 体調が良くなくて、会社を休んだ。
#
# [dict2]  ['良い'] 1
# -1
#
# text: 好きな音楽を聴くと気分が明るくなる。
#
# [dict1]  好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# 2
#
# text: 友達と映画を見に行ったけど、感動して泣いちゃった。
#
# [dict1]  友達 1
# [dict1]  感動 1
# 2
#
# text: 新しいプロジェクトが始まって、やる気満々。
#
# [dict1]  やる気 1
# 1
#
# text: 彼女との旅行が楽しみで、待ちきれない。
#
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# 2
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# 3
#
# text: 好きなドラマの新シーズンが始まって嬉しい。
#
# [dict1]  好き 1
# [dict1]  新 0
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
#
# [dict1]  久しぶり 0
# [dict1]  休み 0
# 0
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# 2
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# -1
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 仕事が忙しくてストレスが溜まっている。
#
# [dict1]  仕事 0
# [dict1]  ストレス -1
# [dict2]  ['忙しい'] -1
# -2
#
# text: ペットが病気になって心配でたまらない。早く元気になって。
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# -2
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 猫が膝の上に乗ってきて、癒された。
#
# [dict2]  ['癒す'] 1
# 1
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 友達とアウトドアに出かけて、楽しかった。
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# 2
#
# text: 新しいレシピを試してみたら、美味しくできた。
#
# [dict2]  ['美味しい'] 1
# 1
#
# text: 久しぶりに会った友達と話して、元気が出た。
#
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# 2
#
# text: 昇進が決まって、とても嬉しい。
#
# [dict1]  昇進 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 仕事が終わって家に帰ると、ホッとする。
#
# [dict1]  仕事 0
# 0
#
# text: 映画館で見た映画がとても面白かった。
#
# [dict2]  ['面白い'] 1
# 1
#
# text: 長時間の会議で疲れ果ててしまった。
#
# [dict1]  長時間 0
# [dict2]  ['疲れる'] -1
# -1
#
# text: 今日は誕生日で、たくさんのメッセージをもらった。
#
# [dict1]  誕生 1
# [dict1]  たくさん 0
# 1
#
# text: 旅行の計画を立てているときが一番ワクワクする。
#
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# 3
#
# text: 試合に勝って、チーム全員で喜んだ。
#
# [dict2]  ['勝つ'] 1
# [dict2]  ['喜ぶ'] 1
# 2
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# 3
#
# text: 今日は特に何もない一日だったけど、それも悪くない。
#
# [dict2]  ['悪い'] -1
# 1
#
# text: 新しいゲームを始めて、ハマってしまった。
#
# [dict1]  ゲーム 0
# 0
#
# text: 友達の結婚式に参加して、幸せな気持ちになった。```
#
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 3

# %%
polar_estimator.estimate_v4("電車が遅れてイライラするけど、仕方がない。", verbose=True)
# Out:
# 電車	名詞,一般,*,*,*,*,電車,デンシャ,デンシャ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 遅れ	動詞,自立,*,*,一段,連用形,遅れる,オクレ,オクレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# イライラ	副詞,助詞類接続,*,*,*,*,イライラ,イライラ,イライラ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 電車が遅れてイライラする
# [dict2]  ['遅れる'] -1
# [e_v4]"電車が遅れてイライラする":-1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 仕方	名詞,ナイ形容詞語幹,*,*,*,*,仕方,シカタ,シカタ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、仕方がない。
# [dict2]  ['仕方', 'が', 'ない'] -1
# [e_v4]"、仕方がない。":-1
# -0.5

# %%
with open("../data/data_ans.txt", "r", encoding="UTF-8") as f:
    data_text_with_ans = f.readlines()
l_pol_and_text=[]
for l in data_text_with_ans:
    pol_and_text=l.split(" ")
    pol_and_text[1]=pol_and_text[1].replace("\n","")
    
    l_pol_and_text.append(pol_and_text)
def pol_to_sign(pol:str)->int:
    if(pol=="e"):
        return 0
    if(pol=="n"):
        return -1
    if(pol=="p"):
        return 1
    return None

# %%
count_diff = 0
failed_list=[]
for t in l_pol_and_text:
    score = polar_estimator.estimate_v4(t[1])
    pol_sign = pol_to_sign(t[0])
    success = True
    if(pol_sign==0):
        if(score!=0):
            success=False
    elif(pol_sign*score<=0):
        success=False
    if not success:
        count_diff+=1
        failed_list.append(t)
for t in l_pol_and_text:
    print("↓")
    print(t)
    print("======")
    score = polar_estimator.estimate_v4(t[1], verbose=True)
    pol_sign = pol_to_sign(t[0])
    print("evaluated score:",score,", ans:",pol_sign)
    print("↑")
print("sum of number  of diffs:",count_diff)
# Out:
# ↓
# ['n', '雨が降ってるから気分が落ち込む。早く晴れてほしいな。']
# ======
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# てる	動詞,非自立,*,*,一段,基本形,てる,テル,テル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 落ち込む	動詞,自立,*,*,五段・マ行,基本形,落ち込む,オチコム,オチコム
# 。	記号,句点,*,*,*,*,。,。,。
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# 晴れ	動詞,自立,*,*,一段,連用形,晴れる,ハレ,ハレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ほしい	形容詞,非自立,*,*,形容詞・イ段,基本形,ほしい,ホシイ,ホシイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
# [dict1]  雨 0
# [dict1]  気分 0
# [dict2]  ['落ち込む'] -1
# [dict2]  ['晴れる'] 1
# [e_v4]"雨が降ってるから気分が落ち込む。早く晴れてほしいな。":0
# evaluated score: 0 , ans: -1
# ↑
# ↓
# ['p', '友達と映画を見に行ったけど、感動して泣いちゃった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 友達と映画を見に行った
# [dict1]  友達 1
# [e_v4]"友達と映画を見に行った":1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 感動	名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 泣い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,泣く,ナイ,ナイ
# ちゃっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,ちゃう,チャッ,チャッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、感動して泣いちゃった。
# [dict1]  感動 1
# [e_v4]"、感動して泣いちゃった。":1
# evaluated score: 0.5 , ans: 1
# ↑
# ↓
# ['p', '新しい仕事が始まって緊張するけど、頑張りたい。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 緊張	名詞,サ変接続,*,*,*,*,緊張,キンチョウ,キンチョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 新しい仕事が始まって緊張する
# [dict1]  仕事 0
# [dict1]  緊張 -1
# [e_v4]"新しい仕事が始まって緊張する":-1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 頑張り	動詞,自立,*,*,五段・ラ行,連用形,頑張る,ガンバリ,ガンバリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、頑張りたい。
# [dict2]  ['頑張る'] 1
# [e_v4]"、頑張りたい。":1
# evaluated score: 1.5 , ans: 1
# ↑
# ↓
# ['p', '美味しいケーキを食べて、幸せな気持ちになった。']
# ======
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# ケーキ	名詞,一般,*,*,*,*,ケーキ,ケーキ,ケーキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 食べ	動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 美味しいケーキを食べて、幸せな気持ちになった。
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [dict2]  ['美味しい'] 1
# [e_v4]"美味しいケーキを食べて、幸せな気持ちになった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['n', 'ペットが病気になって心配でたまらない。早く元気になって。']
# ======
# ペット	名詞,一般,*,*,*,*,ペット,ペット,ペット
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 病気	名詞,サ変接続,*,*,*,*,病気,ビョウキ,ビョーキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 心配	名詞,サ変接続,*,*,*,*,心配,シンパイ,シンパイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# たまらない	形容詞,自立,*,*,形容詞・アウオ段,基本形,たまらない,タマラナイ,タマラナイ
# 。	記号,句点,*,*,*,*,。,。,。
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# 元気	名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 。	記号,句点,*,*,*,*,。,。,。
# text: ペットが病気になって心配でたまらない。早く元気になって。
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# [e_v4]"ペットが病気になって心配でたまらない。早く元気になって。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '家族と一緒に過ごす時間がとても楽しかった。']
# ======
# 家族	名詞,一般,*,*,*,*,家族,カゾク,カゾク
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 一緒	名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 過ごす	動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 楽しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 家族と一緒に過ごす時間がとても楽しかった。
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# [e_v4]"家族と一緒に過ごす時間がとても楽しかった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '仕事でミスをして上司に叱られてしまった。反省しないと。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# ミス	名詞,サ変接続,*,*,*,*,ミス,ミス,ミス
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 上司	名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 叱ら	動詞,自立,*,*,五段・ラ行,未然形,叱る,シカラ,シカラ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 反省	名詞,サ変接続,*,*,*,*,反省,ハンセイ,ハンセイ
# し	動詞,自立,*,*,サ変・スル,未然形,する,シ,シ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事でミスをして上司に叱られてしまった。反省しないと。
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict1]  反省 0
# [e_v4]"仕事でミスをして上司に叱られてしまった。反省しないと。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '旅行の計画を立てているときが一番ワクワクする。']
# ======
# 旅行	名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 計画	名詞,サ変接続,*,*,*,*,計画,ケイカク,ケイカク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 立て	動詞,自立,*,*,一段,連用形,立てる,タテ,タテ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 一番	名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン
# ワクワク	副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 旅行の計画を立てているときが一番ワクワクする。
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# [e_v4]"旅行の計画を立てているときが一番ワクワクする。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '久しぶりに会った友達と話して、元気が出た。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 会っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,会う,アッ,アッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 話し	動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 元気	名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに会った友達と話して、元気が出た。
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# [e_v4]"久しぶりに会った友達と話して、元気が出た。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '電車が遅れてイライラするけど、仕方がない。']
# ======
# 電車	名詞,一般,*,*,*,*,電車,デンシャ,デンシャ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 遅れ	動詞,自立,*,*,一段,連用形,遅れる,オクレ,オクレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# イライラ	副詞,助詞類接続,*,*,*,*,イライラ,イライラ,イライラ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 電車が遅れてイライラする
# [dict2]  ['遅れる'] -1
# [e_v4]"電車が遅れてイライラする":-1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 仕方	名詞,ナイ形容詞語幹,*,*,*,*,仕方,シカタ,シカタ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、仕方がない。
# [dict2]  ['仕方', 'が', 'ない'] -1
# [e_v4]"、仕方がない。":-1
# evaluated score: -0.5 , ans: -1
# ↑
# ↓
# ['p', '新しい趣味を見つけて、毎日が楽しい。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 趣味	名詞,一般,*,*,*,*,趣味,シュミ,シュミ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 毎日	名詞,固有名詞,組織,*,*,*,毎日,マイニチ,マイニチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しい	形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい趣味を見つけて、毎日が楽しい。
# [dict1]  趣味 0
# [dict2]  ['楽しい'] 1
# [e_v4]"新しい趣味を見つけて、毎日が楽しい。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '彼氏とのデートで素敵なレストランに行って幸せ。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# デート	名詞,サ変接続,*,*,*,*,デート,デート,デート
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 素敵	名詞,形容動詞語幹,*,*,*,*,素敵,ステキ,ステキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# レストラン	名詞,一般,*,*,*,*,レストラン,レストラン,レストラン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼氏とのデートで素敵なレストランに行って幸せ。
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  幸せ 1
# [e_v4]"彼氏とのデートで素敵なレストランに行って幸せ。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '今日も一日がんばった。自分を褒めたい気分。']
# ======
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# がんばっ	動詞,自立,*,*,五段・ラ行,連用タ接続,がんばる,ガンバッ,ガンバッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 褒め	動詞,自立,*,*,一段,連用形,褒める,ホメ,ホメ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# 。	記号,句点,*,*,*,*,。,。,。
# text: 今日も一日がんばった。自分を褒めたい気分。
# [dict1]  自分 0
# [dict1]  気分 0
# [e_v4]"今日も一日がんばった。自分を褒めたい気分。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['n', '雨の日はどうしても気分が沈んでしまう。']
# ======
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 日	名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どうしても	副詞,一般,*,*,*,*,どうしても,ドウシテモ,ドーシテモ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 沈ん	動詞,自立,*,*,五段・マ行,連用タ接続,沈む,シズン,シズン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# しまう	動詞,非自立,*,*,五段・ワ行促音便,基本形,しまう,シマウ,シマウ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雨の日はどうしても気分が沈んでしまう。
# [dict1]  雨 0
# [dict1]  気分 0
# [e_v4]"雨の日はどうしても気分が沈んでしまう。":0
# evaluated score: 0 , ans: -1
# ↑
# ↓
# ['p', '大好きな音楽を聴くと気分が明るくなる。']
# ======
# 大好き	名詞,形容動詞語幹,*,*,*,*,大好き,ダイスキ,ダイスキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 音楽	名詞,一般,*,*,*,*,音楽,オンガク,オンガク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 聴く	動詞,自立,*,*,五段・カ行イ音便,基本形,聴く,キク,キク
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 明るく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,明るい,アカルク,アカルク
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 大好きな音楽を聴くと気分が明るくなる。
# [dict1]  大好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# [e_v4]"大好きな音楽を聴くと気分が明るくなる。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '試験の結果が悪くて、落ち込んでしまった。']
# ======
# 試験	名詞,サ変接続,*,*,*,*,試験,シケン,シケン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 結果	名詞,副詞可能,*,*,*,*,結果,ケッカ,ケッカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 落ち込ん	動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 試験の結果が悪くて、落ち込んでしまった。
# [dict1]  試験 -1
# [dict2]  ['悪い'] -1
# [dict2]  ['落ち込む'] -1
# [e_v4]"試験の結果が悪くて、落ち込んでしまった。":-3
# evaluated score: -3 , ans: -1
# ↑
# ↓
# ['p', '彼女からのサプライズプレゼントに感動した。']
# ======
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# サプライズプレゼント	名詞,一般,*,*,*,*,サプライズプレゼント,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 感動	名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼女からのサプライズプレゼントに感動した。
# [dict1]  感動 1
# [e_v4]"彼女からのサプライズプレゼントに感動した。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '久しぶりに休みが取れて、ゆっくり休むことができた。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 休み	名詞,一般,*,*,*,*,休み,ヤスミ,ヤスミ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 取れ	動詞,自立,*,*,一段,連用形,取れる,トレ,トレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 休む	動詞,自立,*,*,五段・マ行,基本形,休む,ヤスム,ヤスム
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
# [dict1]  久しぶり 0
# [dict1]  休み 0
# [e_v4]"久しぶりに休みが取れて、ゆっくり休むことができた。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['n', '仕事が忙しくてストレスが溜まっている。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 忙しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,忙しい,イソガシク,イソガシク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ストレス	名詞,一般,*,*,*,*,ストレス,ストレス,ストレス
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 溜まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,溜まる,タマッ,タマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事が忙しくてストレスが溜まっている。
# [dict1]  仕事 0
# [dict1]  ストレス -1
# [dict2]  ['忙しい'] -1
# [e_v4]"仕事が忙しくてストレスが溜まっている。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['n', '友達と喧嘩してしまって、悲しい気持ちになった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 悲しい	形容詞,自立,*,*,形容詞・イ段,基本形,悲しい,カナシイ,カナシイ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達と喧嘩してしまって、悲しい気持ちになった。
# [dict1]  友達 1
# [dict1]  喧嘩 -1
# [dict1]  気持ち 1
# [dict2]  ['悲しい'] -1
# [e_v4]"友達と喧嘩してしまって、悲しい気持ちになった。":0
# evaluated score: 0 , ans: -1
# ↑
# ↓
# ['p', '新しい洋服を買って、気分が上がった。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 洋服	名詞,一般,*,*,*,*,洋服,ヨウフク,ヨーフク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 上がっ	動詞,自立,*,*,五段・ラ行,連用タ接続,上がる,アガッ,アガッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい洋服を買って、気分が上がった。
# [dict1]  気分 0
# [e_v4]"新しい洋服を買って、気分が上がった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '猫と一緒に過ごす時間が一番の癒し。']
# ======
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 一緒	名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 過ごす	動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 一番	名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 癒し	動詞,自立,*,*,五段・サ行,連用形,癒す,イヤシ,イヤシ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 猫と一緒に過ごす時間が一番の癒し。
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# [e_v4]"猫と一緒に過ごす時間が一番の癒し。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['e', '今日は特に何もない一日だったけど、それも悪くない。']
# ======
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 特に	副詞,一般,*,*,*,*,特に,トクニ,トクニ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 今日は特に何もない一日だった
# [e_v4]"今日は特に何もない一日だった":0*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、それも悪くない。
# [dict2]  ['悪い'] -1
# [e_v4]"、それも悪くない。":1
# evaluated score: 1.0 , ans: 0
# ↑
# ↓
# ['p', '親友と久しぶりに再会して、楽しい時間を過ごした。']
# ======
# 親友	名詞,一般,*,*,*,*,親友,シンユウ,シンユー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 再会	名詞,サ変接続,*,*,*,*,再会,サイカイ,サイカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 楽しい	形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 過ごし	動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 親友と久しぶりに再会して、楽しい時間を過ごした。
# [dict1]  親友 1
# [dict1]  久しぶり 0
# [dict1]  再会 0
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# [e_v4]"親友と久しぶりに再会して、楽しい時間を過ごした。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '好きなドラマの新シーズンが始まって嬉しい。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ドラマ	名詞,一般,*,*,*,*,ドラマ,ドラマ,ドラマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# シーズン	名詞,一般,*,*,*,*,シーズン,シーズン,シーズン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きなドラマの新シーズンが始まって嬉しい。
# [dict1]  好き 1
# [dict1]  新 0
# [dict2]  ['嬉しい'] 1
# [e_v4]"好きなドラマの新シーズンが始まって嬉しい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '失恋してからなかなか立ち直れない。']
# ======
# 失恋	名詞,サ変接続,*,*,*,*,失恋,シツレン,シツレン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# なかなか	副詞,助詞類接続,*,*,*,*,なかなか,ナカナカ,ナカナカ
# 立ち直れ	動詞,自立,*,*,一段,未然形,立ち直れる,タチナオレ,タチナオレ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 失恋してからなかなか立ち直れない。
# [dict1]  失恋 -1
# [e_v4]"失恋してからなかなか立ち直れない。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '仕事のプレゼンがうまくいって、自信がついた。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プレゼン	名詞,サ変接続,*,*,*,*,プレゼン,プレゼン,プレゼン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# うまく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,うまい,ウマク,ウマク
# いっ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,いく,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 自信	名詞,一般,*,*,*,*,自信,ジシン,ジシン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# つい	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事のプレゼンがうまくいって、自信がついた。
# [dict1]  仕事 0
# [dict1]  自信 1
# [dict2]  ['うまい'] 1
# [e_v4]"仕事のプレゼンがうまくいって、自信がついた。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '朝から体調が悪くて、一日中寝ていた。']
# ======
# 朝	名詞,副詞可能,*,*,*,*,朝,アサ,アサ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# 中	名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー
# 寝	動詞,自立,*,*,一段,連用形,寝る,ネ,ネ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 朝から体調が悪くて、一日中寝ていた。
# [dict1]  朝 0
# [dict1]  中 0
# [dict2]  ['悪い'] -1
# [e_v4]"朝から体調が悪くて、一日中寝ていた。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '散歩中に見た夕日がとても綺麗だった。']
# ======
# 散歩	名詞,サ変接続,*,*,*,*,散歩,サンポ,サンポ
# 中	名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 夕日	名詞,一般,*,*,*,*,夕日,ユウヒ,ユーヒ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 綺麗	名詞,形容動詞語幹,*,*,*,*,綺麗,キレイ,キレイ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 散歩中に見た夕日がとても綺麗だった。
# [dict1]  散歩 1
# [dict1]  中 0
# [dict1]  綺麗 1
# [e_v4]"散歩中に見た夕日がとても綺麗だった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '新しいレシピを試してみたら、美味しくできた。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# レシピ	名詞,一般,*,*,*,*,レシピ,レシピ,レシピ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# 、	記号,読点,*,*,*,*,、,、,、
# 美味しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,美味しい,オイシク,オイシク
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいレシピを試してみたら、美味しくできた。
# [dict2]  ['美味しい'] 1
# [e_v4]"新しいレシピを試してみたら、美味しくできた。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '同僚に助けられて、感謝の気持ちでいっぱい。']
# ======
# 同僚	名詞,一般,*,*,*,*,同僚,ドウリョウ,ドーリョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 助け	動詞,自立,*,*,一段,未然形,助ける,タスケ,タスケ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 感謝	名詞,サ変接続,*,*,*,*,感謝,カンシャ,カンシャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# いっぱい	副詞,一般,*,*,*,*,いっぱい,イッパイ,イッパイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 同僚に助けられて、感謝の気持ちでいっぱい。
# [dict1]  感謝 1
# [dict1]  気持ち 1
# [dict1]  いっぱい 0
# [e_v4]"同僚に助けられて、感謝の気持ちでいっぱい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '彼氏との電話が楽しくて、夜更かししてしまった。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 電話	名詞,サ変接続,*,*,*,*,電話,デンワ,デンワ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,楽しい,タノシク,タノシク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
# 更かし	動詞,自立,*,*,五段・サ行,連用形,更かす,フカシ,フカシ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
# [dict2]  ['楽しい'] 1
# [e_v4]"彼氏との電話が楽しくて、夜更かししてしまった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', 'スポーツジムで体を動かして、スッキリした。']
# ======
# スポーツ	名詞,一般,*,*,*,*,スポーツ,スポーツ,スポーツ
# ジム	名詞,一般,*,*,*,*,ジム,ジム,ジム
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 体	名詞,一般,*,*,*,*,体,カラダ,カラダ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 動かし	動詞,自立,*,*,五段・サ行,連用形,動かす,ウゴカシ,ウゴカシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# スッキリ	副詞,助詞類接続,*,*,*,*,スッキリ,スッキリ,スッキリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: スポーツジムで体を動かして、スッキリした。
# [dict1]  スポーツ 0
# [e_v4]"スポーツジムで体を動かして、スッキリした。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '雨上がりの虹を見て、心が洗われるようだった。']
# ======
# 雨上がり	名詞,一般,*,*,*,*,雨上がり,アメアガリ,アメアガリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 虹	名詞,一般,*,*,*,*,虹,ニジ,ニジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 心	名詞,一般,*,*,*,*,心,ココロ,ココロ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 洗わ	動詞,自立,*,*,五段・ワ行促音便,未然形,洗う,アラワ,アラワ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雨上がりの虹を見て、心が洗われるようだった。
# [e_v4]"雨上がりの虹を見て、心が洗われるようだった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '試合に勝って、チーム全員で喜んだ。']
# ======
# 試合	名詞,サ変接続,*,*,*,*,試合,シアイ,シアイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 勝っ	動詞,自立,*,*,五段・タ行,連用タ接続,勝つ,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# チーム	名詞,一般,*,*,*,*,チーム,チーム,チーム
# 全員	名詞,一般,*,*,*,*,全員,ゼンイン,ゼンイン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 喜ん	動詞,自立,*,*,五段・バ行,連用タ接続,喜ぶ,ヨロコン,ヨロコン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 試合に勝って、チーム全員で喜んだ。
# [dict2]  ['勝つ'] 1
# [dict2]  ['喜ぶ'] 1
# [e_v4]"試合に勝って、チーム全員で喜んだ。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '今日は誕生日で、たくさんのメッセージをもらった。']
# ======
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 誕生	名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# たくさん	名詞,副詞可能,*,*,*,*,たくさん,タクサン,タクサン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メッセージ	名詞,一般,*,*,*,*,メッセージ,メッセージ,メッセージ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# もらっ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 今日は誕生日で、たくさんのメッセージをもらった。
# [dict1]  誕生 1
# [dict1]  たくさん 0
# [e_v4]"今日は誕生日で、たくさんのメッセージをもらった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', 'ミスをしてしまって、上司に怒られて落ち込んだ。']
# ======
# ミス	名詞,サ変接続,*,*,*,*,ミス,ミス,ミス
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 上司	名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 怒ら	動詞,自立,*,*,五段・ラ行,未然形,怒る,オコラ,オコラ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 落ち込ん	動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# text: ミスをしてしまって、上司に怒られて落ち込んだ。
# [dict1]  ミス -1
# [dict2]  ['怒る'] -1
# [dict2]  ['落ち込む'] -1
# [e_v4]"ミスをしてしまって、上司に怒られて落ち込んだ。":-3
# evaluated score: -3 , ans: -1
# ↑
# ↓
# ['p', '久しぶりに母の手料理を食べて、懐かしい気分になった。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 母	名詞,一般,*,*,*,*,母,ハハ,ハハ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 手料理	名詞,一般,*,*,*,*,手料理,テリョウリ,テリョーリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 食べ	動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 懐かしい	形容詞,自立,*,*,形容詞・イ段,基本形,懐かしい,ナツカシイ,ナツカシイ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに母の手料理を食べて、懐かしい気分になった。
# [dict1]  久しぶり 0
# [dict1]  気分 0
# [e_v4]"久しぶりに母の手料理を食べて、懐かしい気分になった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '面白い本を見つけて、読みふけってしまった。']
# ======
# 面白い	形容詞,自立,*,*,形容詞・アウオ段,基本形,面白い,オモシロイ,オモシロイ
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 読みふけっ	動詞,自立,*,*,五段・ラ行,連用タ接続,読みふける,ヨミフケッ,ヨミフケッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 面白い本を見つけて、読みふけってしまった。
# [dict2]  ['面白い'] 1
# [e_v4]"面白い本を見つけて、読みふけってしまった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '友達の結婚式に参加して、幸せな気持ちになった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 結婚式	名詞,一般,*,*,*,*,結婚式,ケッコンシキ,ケッコンシキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 参加	名詞,サ変接続,*,*,*,*,参加,サンカ,サンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達の結婚式に参加して、幸せな気持ちになった。
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [e_v4]"友達の結婚式に参加して、幸せな気持ちになった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['n', '風邪をひいてしまって、ずっと寝ている。']
# ======
# 風邪	名詞,一般,*,*,*,*,風邪,カゼ,カゼ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# ひい	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,ひく,ヒイ,ヒイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ずっと	副詞,一般,*,*,*,*,ずっと,ズット,ズット
# 寝	動詞,自立,*,*,一段,連用形,寝る,ネ,ネ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 風邪をひいてしまって、ずっと寝ている。
# [dict1]  風邪 -1
# [e_v4]"風邪をひいてしまって、ずっと寝ている。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '新しいゲームを始めて、ハマってしまった。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ゲーム	名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 始め	動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ハマっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいゲームを始めて、ハマってしまった。
# [dict1]  ゲーム 0
# [e_v4]"新しいゲームを始めて、ハマってしまった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '猫が膝の上に乗ってきて、癒された。']
# ======
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 膝	名詞,一般,*,*,*,*,膝,ヒザ,ヒザ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 上	名詞,非自立,副詞可能,*,*,*,上,ウエ,ウエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 乗っ	動詞,自立,*,*,五段・ラ行,連用タ接続,乗る,ノッ,ノッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 癒さ	動詞,自立,*,*,五段・サ行,未然形,癒す,イヤサ,イヤサ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 猫が膝の上に乗ってきて、癒された。
# [dict2]  ['癒す'] 1
# [e_v4]"猫が膝の上に乗ってきて、癒された。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '長い一日が終わって、ほっと一息ついた。']
# ======
# 長い	形容詞,自立,*,*,形容詞・アウオ段,基本形,長い,ナガイ,ナガイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ほっと	副詞,一般,*,*,*,*,ほっと,ホット,ホット
# 一息	名詞,一般,*,*,*,*,一息,ヒトイキ,ヒトイキ
# つい	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 長い一日が終わって、ほっと一息ついた。
# [e_v4]"長い一日が終わって、ほっと一息ついた。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '昇進が決まって、とても嬉しい。']
# ======
# 昇進	名詞,サ変接続,*,*,*,*,昇進,ショウシン,ショーシン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 決まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,決まる,キマッ,キマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 昇進が決まって、とても嬉しい。
# [dict1]  昇進 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"昇進が決まって、とても嬉しい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', 'お風呂に入ってリラックスする時間が好き。']
# ======
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 風呂	名詞,一般,*,*,*,*,風呂,フロ,フロ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 入っ	動詞,自立,*,*,五段・ラ行,連用タ接続,入る,ハイッ,ハイッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# リラックス	名詞,サ変接続,*,*,*,*,リラックス,リラックス,リラックス
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# 。	記号,句点,*,*,*,*,。,。,。
# text: お風呂に入ってリラックスする時間が好き。
# [dict1]  リラックス 1
# [dict1]  時間 0
# [dict1]  好き 1
# [e_v4]"お風呂に入ってリラックスする時間が好き。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '友達とカフェでおしゃべりして、楽しい時間を過ごした。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# カフェ	名詞,一般,*,*,*,*,カフェ,カフェ,カフェ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# おしゃべり	名詞,サ変接続,*,*,*,*,おしゃべり,オシャベリ,オシャベリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 楽しい	形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 過ごし	動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とカフェでおしゃべりして、楽しい時間を過ごした。
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とカフェでおしゃべりして、楽しい時間を過ごした。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '自分の作品が認められて、嬉しい気持ちになった。']
# ======
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 作品	名詞,一般,*,*,*,*,作品,サクヒン,サクヒン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 認め	動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 自分の作品が認められて、嬉しい気持ちになった。
# [dict1]  自分 0
# [dict1]  気持ち 1
# [dict2]  ['認める'] 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"自分の作品が認められて、嬉しい気持ちになった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '会議が長引いて疲れたけど、達成感がある。']
# ======
# 会議	名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 長引い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,長引く,ナガビイ,ナガビイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 会議が長引いて疲れた
# [dict2]  ['疲れる'] -1
# [e_v4]"会議が長引いて疲れた":-1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 達成	名詞,サ変接続,*,*,*,*,達成,タッセイ,タッセイ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、達成感がある。
# [dict1]  達成 1
# [e_v4]"、達成感がある。":1
# evaluated score: 1.5 , ans: 1
# ↑
# ↓
# ['p', '彼女との旅行が楽しみで、待ちきれない。']
# ======
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 旅行	名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しみ	名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 待ち	動詞,自立,*,*,五段・タ行,連用形,待つ,マチ,マチ
# きれ	動詞,非自立,*,*,一段,未然形,きれる,キレ,キレ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼女との旅行が楽しみで、待ちきれない。
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# [e_v4]"彼女との旅行が楽しみで、待ちきれない。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '仕事が終わって家に帰ると、ホッとする。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 家	名詞,一般,*,*,*,*,家,イエ,イエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 帰る	動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# ホッ	副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事が終わって家に帰ると、ホッとする。
# [dict1]  仕事 0
# [e_v4]"仕事が終わって家に帰ると、ホッとする。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '好きなバンドのライブに行って、最高の夜だった。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# バンド	名詞,一般,*,*,*,*,バンド,バンド,バンド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ライブ	名詞,一般,*,*,*,*,ライブ,ライブ,ライブ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 最高	名詞,一般,*,*,*,*,最高,サイコウ,サイコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きなバンドのライブに行って、最高の夜だった。
# [dict1]  好き 1
# [dict1]  最高 1
# [e_v4]"好きなバンドのライブに行って、最高の夜だった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '忙しい日々が続いていて、少し疲れている。']
# ======
# 忙しい	形容詞,自立,*,*,形容詞・イ段,基本形,忙しい,イソガシイ,イソガシイ
# 日々	名詞,副詞可能,*,*,*,*,日々,ヒビ,ヒビ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 続い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,続く,ツヅイ,ツズイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 忙しい日々が続いていて、少し疲れている。
# [dict2]  ['忙しい'] -1
# [dict2]  ['疲れる'] -1
# [e_v4]"忙しい日々が続いていて、少し疲れている。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['p', '彼氏からのサプライズに驚いて、嬉しかった。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# サプライズ	名詞,一般,*,*,*,*,サプライズ,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 驚い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,驚く,オドロイ,オドロイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 嬉しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,嬉しい,ウレシカッ,ウレシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼氏からのサプライズに驚いて、嬉しかった。
# [dict2]  ['嬉しい'] 1
# [e_v4]"彼氏からのサプライズに驚いて、嬉しかった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '親友と大喧嘩してしまって、後悔している。']
# ======
# 親友	名詞,一般,*,*,*,*,親友,シンユウ,シンユー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 大	接頭詞,名詞接続,*,*,*,*,大,ダイ,ダイ
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 後悔	名詞,サ変接続,*,*,*,*,後悔,コウカイ,コーカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 親友と大喧嘩してしまって、後悔している。
# [dict1]  親友 1
# [dict1]  喧嘩 -1
# [dict1]  後悔 -1
# [e_v4]"親友と大喧嘩してしまって、後悔している。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '美味しいラーメンを食べて、幸せな気持ちになった。']
# ======
# 美味しい	形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ
# ラーメン	名詞,一般,*,*,*,*,ラーメン,ラーメン,ラーメン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 食べ	動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 美味しいラーメンを食べて、幸せな気持ちになった。
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [dict2]  ['美味しい'] 1
# [e_v4]"美味しいラーメンを食べて、幸せな気持ちになった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['n', '風が強くて、外に出るのが億劫だった。']
# ======
# 風	名詞,一般,*,*,*,*,風,カゼ,カゼ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 強く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,強い,ツヨク,ツヨク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 外	名詞,一般,*,*,*,*,外,ソト,ソト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 出る	動詞,自立,*,*,一段,基本形,出る,デル,デル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 億劫	名詞,形容動詞語幹,*,*,*,*,億劫,オックウ,オックー
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 風が強くて、外に出るのが億劫だった。
# [e_v4]"風が強くて、外に出るのが億劫だった。":0
# evaluated score: 0 , ans: -1
# ↑
# ↓
# ['p', '新しいプロジェクトが始まって、やる気満々。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# プロジェクト	名詞,一般,*,*,*,*,プロジェクト,プロジェクト,プロジェクト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# やる気	名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ
# 満々	名詞,一般,*,*,*,*,満々,マンマン,マンマン
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいプロジェクトが始まって、やる気満々。
# [dict1]  やる気 1
# [e_v4]"新しいプロジェクトが始まって、やる気満々。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '長時間の会議で疲れ果ててしまった。']
# ======
# 長時間	名詞,副詞可能,*,*,*,*,長時間,チョウジカン,チョージカン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 会議	名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# 果て	動詞,自立,*,*,一段,連用形,果てる,ハテ,ハテ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 長時間の会議で疲れ果ててしまった。
# [dict1]  長時間 0
# [dict2]  ['疲れる'] -1
# [e_v4]"長時間の会議で疲れ果ててしまった。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '久しぶりに海に行って、リフレッシュできた。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 海	名詞,一般,*,*,*,*,海,ウミ,ウミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# リフレッシュ	名詞,サ変接続,*,*,*,*,リフレッシュ,リフレッシュ,リフレッシュ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに海に行って、リフレッシュできた。
# [dict1]  久しぶり 0
# [dict1]  リフレッシュ 1
# [e_v4]"久しぶりに海に行って、リフレッシュできた。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '試験勉強が大変で、ストレスが溜まっている。']
# ======
# 試験	名詞,サ変接続,*,*,*,*,試験,シケン,シケン
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# ストレス	名詞,一般,*,*,*,*,ストレス,ストレス,ストレス
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 溜まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,溜まる,タマッ,タマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 試験勉強が大変で、ストレスが溜まっている。
# [dict1]  試験 -1
# [dict1]  大変 -1
# [dict1]  ストレス -1
# [e_v4]"試験勉強が大変で、ストレスが溜まっている。":-3
# evaluated score: -3 , ans: -1
# ↑
# ↓
# ['p', '友達の赤ちゃんが生まれて、とても嬉しい。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 赤ちゃん	名詞,一般,*,*,*,*,赤ちゃん,アカチャン,アカチャン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 生まれ	動詞,自立,*,*,一段,連用形,生まれる,ウマレ,ウマレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
# [dict1]  友達 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"友達の赤ちゃんが生まれて、とても嬉しい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', 'プレゼントをもらって、心が温まった。']
# ======
# プレゼント	名詞,サ変接続,*,*,*,*,プレゼント,プレゼント,プレゼント
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# もらっ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 心	名詞,一般,*,*,*,*,心,ココロ,ココロ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 温まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,温まる,アタタマッ,アタタマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: プレゼントをもらって、心が温まった。
# [dict1]  プレゼント 1
# [dict2]  ['温まる'] 1
# [e_v4]"プレゼントをもらって、心が温まった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '好きなアーティストのコンサートが楽しみ。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# アーティスト	名詞,一般,*,*,*,*,アーティスト,アーティスト,アーティスト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コンサート	名詞,一般,*,*,*,*,コンサート,コンサート,コンサート
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しみ	名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きなアーティストのコンサートが楽しみ。
# [dict1]  好き 1
# [dict1]  アーティスト 0
# [dict1]  楽しみ 1
# [e_v4]"好きなアーティストのコンサートが楽しみ。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['e', '雨の日は読書に限ると、改めて感じた。']
# ======
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 日	名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 読書	名詞,サ変接続,*,*,*,*,読書,ドクショ,ドクショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 限る	動詞,自立,*,*,五段・ラ行,基本形,限る,カギル,カギル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 改めて	副詞,一般,*,*,*,*,改めて,アラタメテ,アラタメテ
# 感じ	動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雨の日は読書に限ると、改めて感じた。
# [dict1]  雨 0
# [e_v4]"雨の日は読書に限ると、改めて感じた。":0
# evaluated score: 0 , ans: 0
# ↑
# ↓
# ['n', '体調が良くなくて、会社を休んだ。']
# ======
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 会社	名詞,一般,*,*,*,*,会社,カイシャ,カイシャ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 休ん	動詞,自立,*,*,五段・マ行,連用タ接続,休む,ヤスン,ヤスン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 体調が良くなくて、会社を休んだ。
# [dict2]  ['良い'] 1
# [e_v4]"体調が良くなくて、会社を休んだ。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '新しい料理に挑戦して、上手くできた。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 料理	名詞,サ変接続,*,*,*,*,料理,リョウリ,リョーリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 挑戦	名詞,サ変接続,*,*,*,*,挑戦,チョウセン,チョーセン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 上手く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,上手い,ウマク,ウマク
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい料理に挑戦して、上手くできた。
# [dict1]  料理 0
# [dict1]  挑戦 0
# [dict2]  ['上手い'] 1
# [e_v4]"新しい料理に挑戦して、上手くできた。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '映画館で見た映画がとても面白かった。']
# ======
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# 館	名詞,接尾,一般,*,*,*,館,カン,カン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 面白かっ	形容詞,自立,*,*,形容詞・アウオ段,連用タ接続,面白い,オモシロカッ,オモシロカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 映画館で見た映画がとても面白かった。
# [dict2]  ['面白い'] 1
# [e_v4]"映画館で見た映画がとても面白かった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '彼氏とケンカして、悲しい気持ちになった。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# ケンカ	名詞,サ変接続,*,*,*,*,ケンカ,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 悲しい	形容詞,自立,*,*,形容詞・イ段,基本形,悲しい,カナシイ,カナシイ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼氏とケンカして、悲しい気持ちになった。
# [dict1]  ケンカ -1
# [dict1]  気持ち 1
# [dict2]  ['悲しい'] -1
# [e_v4]"彼氏とケンカして、悲しい気持ちになった。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '友達とアウトドアに出かけて、楽しかった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# アウトドア	名詞,一般,*,*,*,*,アウトドア,アウトドア,アウトドア
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 出かけ	動詞,自立,*,*,一段,連用形,出かける,デカケ,デカケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 楽しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とアウトドアに出かけて、楽しかった。
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とアウトドアに出かけて、楽しかった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '上司に認められて、やる気が出た。']
# ======
# 上司	名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 認め	動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# やる気	名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 上司に認められて、やる気が出た。
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# [e_v4]"上司に認められて、やる気が出た。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '誕生日プレゼントをもらって、とても嬉しかった。']
# ======
# 誕生	名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# プレゼント	名詞,サ変接続,*,*,*,*,プレゼント,プレゼント,プレゼント
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# もらっ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 嬉しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,嬉しい,ウレシカッ,ウレシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 誕生日プレゼントをもらって、とても嬉しかった。
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"誕生日プレゼントをもらって、とても嬉しかった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '雪が降っていて、外に出るのが楽しみ。']
# ======
# 雪	名詞,一般,*,*,*,*,雪,ユキ,ユキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 外	名詞,一般,*,*,*,*,外,ソト,ソト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 出る	動詞,自立,*,*,一段,基本形,出る,デル,デル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しみ	名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雪が降っていて、外に出るのが楽しみ。
# [dict1]  雪 0
# [dict1]  楽しみ 1
# [e_v4]"雪が降っていて、外に出るのが楽しみ。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['e', '新しいカフェを見つけて、友達と行ってみた。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# カフェ	名詞,一般,*,*,*,*,カフェ,カフェ,カフェ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 行っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいカフェを見つけて、友達と行ってみた。
# [dict1]  友達 1
# [e_v4]"新しいカフェを見つけて、友達と行ってみた。":1
# evaluated score: 1 , ans: 0
# ↑
# ↓
# ['n', '仕事でミスしてしまって、落ち込んでいる。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# ミス	名詞,サ変接続,*,*,*,*,ミス,ミス,ミス
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 落ち込ん	動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事でミスしてしまって、落ち込んでいる。
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# [e_v4]"仕事でミスしてしまって、落ち込んでいる。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['p', '好きなアニメの新作が出て、ワクワクしている。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# アニメ	名詞,一般,*,*,*,*,アニメ,アニメ,アニメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 新作	名詞,サ変接続,*,*,*,*,新作,シンサク,シンサク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ワクワク	副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きなアニメの新作が出て、ワクワクしている。
# [dict1]  好き 1
# [dict1]  新作 0
# [dict2]  ['わくわく'] 1
# [e_v4]"好きなアニメの新作が出て、ワクワクしている。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '体調が悪くて、早退した。']
# ======
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 早退	名詞,サ変接続,*,*,*,*,早退,ソウタイ,ソータイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 体調が悪くて、早退した。
# [dict1]  早退 -1
# [dict2]  ['悪い'] -1
# [e_v4]"体調が悪くて、早退した。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['p', '友達と旅行に行って、最高の思い出ができた。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 旅行	名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 最高	名詞,一般,*,*,*,*,最高,サイコウ,サイコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 思い出	名詞,一般,*,*,*,*,思い出,オモイデ,オモイデ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達と旅行に行って、最高の思い出ができた。
# [dict1]  友達 1
# [dict1]  旅行 1
# [dict1]  最高 1
# [dict1]  思い出 1
# [e_v4]"友達と旅行に行って、最高の思い出ができた。":4
# evaluated score: 4 , ans: 1
# ↑
# ↓
# ['n', '疲れているのに、寝付けない夜が続いている。']
# ======
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# のに	助詞,接続助詞,*,*,*,*,のに,ノニ,ノニ
# text: 疲れている
# [dict2]  ['疲れる'] -1
# [e_v4]"疲れている":-1*"のに":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 寝付け	動詞,自立,*,*,一段,未然形,寝付ける,ネツケ,ネツケ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 続い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,続く,ツヅイ,ツズイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、寝付けない夜が続いている。
# [e_v4]"、寝付けない夜が続いている。":0
# evaluated score: 0.5 , ans: -1
# ↑
# ↓
# ['p', '新しい靴を買って、ウキウキしている。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 靴	名詞,一般,*,*,*,*,靴,クツ,クツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ウキウキ	副詞,一般,*,*,*,*,ウキウキ,ウキウキ,ウキウキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい靴を買って、ウキウキしている。
# [dict2]  ['うきうき'] 1
# [e_v4]"新しい靴を買って、ウキウキしている。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '恋人との記念日を祝って、幸せな時間を過ごした。']
# ======
# 恋人	名詞,一般,*,*,*,*,恋人,コイビト,コイビト
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 記念	名詞,サ変接続,*,*,*,*,記念,キネン,キネン
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 祝っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,祝う,イワッ,イワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 過ごし	動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 恋人との記念日を祝って、幸せな時間を過ごした。
# [dict1]  恋人 1
# [dict1]  記念 0
# [dict1]  幸せ 1
# [dict1]  時間 0
# [e_v4]"恋人との記念日を祝って、幸せな時間を過ごした。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '上司に褒められて、自信がついた。']
# ======
# 上司	名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 褒め	動詞,自立,*,*,一段,未然形,褒める,ホメ,ホメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 自信	名詞,一般,*,*,*,*,自信,ジシン,ジシン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# つい	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 上司に褒められて、自信がついた。
# [dict1]  自信 1
# [e_v4]"上司に褒められて、自信がついた。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '雨の日の静けさが好きで、落ち着く。']
# ======
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 日	名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 静けさ	名詞,一般,*,*,*,*,静けさ,シズケサ,シズケサ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 落ち着く	動詞,自立,*,*,五段・カ行イ音便,基本形,落ち着く,オチツク,オチツク
# 。	記号,句点,*,*,*,*,。,。,。
# text: 雨の日の静けさが好きで、落ち着く。
# [dict1]  雨 0
# [dict1]  静けさ 1
# [dict1]  好き 1
# [dict2]  ['落ち着く'] 1
# [e_v4]"雨の日の静けさが好きで、落ち着く。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '友達とのランチがとても楽しかった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ランチ	名詞,一般,*,*,*,*,ランチ,ランチ,ランチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 楽しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とのランチがとても楽しかった。
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とのランチがとても楽しかった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '仕事で成果を出して、達成感がある。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 成果	名詞,一般,*,*,*,*,成果,セイカ,セイカ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 出し	動詞,自立,*,*,五段・サ行,連用形,出す,ダシ,ダシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 達成	名詞,サ変接続,*,*,*,*,達成,タッセイ,タッセイ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事で成果を出して、達成感がある。
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# [e_v4]"仕事で成果を出して、達成感がある。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', 'お風呂にゆっくり浸かって、リラックスした。']
# ======
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 風呂	名詞,一般,*,*,*,*,風呂,フロ,フロ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 浸かっ	動詞,自立,*,*,五段・ラ行,連用タ接続,浸かる,ツカッ,ツカッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# リラックス	名詞,サ変接続,*,*,*,*,リラックス,リラックス,リラックス
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: お風呂にゆっくり浸かって、リラックスした。
# [dict1]  リラックス 1
# [e_v4]"お風呂にゆっくり浸かって、リラックスした。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '彼女と喧嘩して、気まずい雰囲気になった。']
# ======
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 気まずい	形容詞,自立,*,*,形容詞・アウオ段,基本形,気まずい,キマズイ,キマズイ
# 雰囲気	名詞,一般,*,*,*,*,雰囲気,フンイキ,フンイキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼女と喧嘩して、気まずい雰囲気になった。
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# [e_v4]"彼女と喧嘩して、気まずい雰囲気になった。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '新しい本を読み始めて、止まらなくなった。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 読み	動詞,自立,*,*,五段・マ行,連用形,読む,ヨミ,ヨミ
# 始め	動詞,非自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 止まら	動詞,自立,*,*,五段・ラ行,未然形,止まる,トマラ,トマラ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい本を読み始めて、止まらなくなった。
# [e_v4]"新しい本を読み始めて、止まらなくなった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '大好きなカフェで、ゆっくり過ごす時間が幸せ。']
# ======
# 大好き	名詞,形容動詞語幹,*,*,*,*,大好き,ダイスキ,ダイスキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# カフェ	名詞,一般,*,*,*,*,カフェ,カフェ,カフェ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 過ごす	動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 大好きなカフェで、ゆっくり過ごす時間が幸せ。
# [dict1]  大好き 1
# [dict1]  時間 0
# [dict1]  幸せ 1
# [e_v4]"大好きなカフェで、ゆっくり過ごす時間が幸せ。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '友達の誕生日を祝って、一緒に楽しんだ。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 誕生	名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 祝っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,祝う,イワッ,イワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 一緒	名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 楽しん	動詞,自立,*,*,五段・マ行,連用タ接続,楽しむ,タノシン,タノシン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達の誕生日を祝って、一緒に楽しんだ。
# [dict1]  友達 1
# [dict1]  誕生 1
# [dict1]  一緒 1
# [dict2]  ['楽しむ'] 1
# [e_v4]"友達の誕生日を祝って、一緒に楽しんだ。":4
# evaluated score: 4 , ans: 1
# ↑
# ↓
# ['n', '仕事が忙しくて、なかなか休めない。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 忙しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,忙しい,イソガシク,イソガシク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# なかなか	副詞,助詞類接続,*,*,*,*,なかなか,ナカナカ,ナカナカ
# 休め	動詞,自立,*,*,一段,未然形,休める,ヤスメ,ヤスメ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事が忙しくて、なかなか休めない。
# [dict1]  仕事 0
# [dict2]  ['忙しい'] -1
# [e_v4]"仕事が忙しくて、なかなか休めない。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '好きな映画を見て、リフレッシュできた。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# リフレッシュ	名詞,サ変接続,*,*,*,*,リフレッシュ,リフレッシュ,リフレッシュ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きな映画を見て、リフレッシュできた。
# [dict1]  好き 1
# [dict1]  リフレッシュ 1
# [e_v4]"好きな映画を見て、リフレッシュできた。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '新しい趣味を見つけて、毎日が楽しい。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 趣味	名詞,一般,*,*,*,*,趣味,シュミ,シュミ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 毎日	名詞,固有名詞,組織,*,*,*,毎日,マイニチ,マイニチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しい	形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい趣味を見つけて、毎日が楽しい。
# [dict1]  趣味 0
# [dict2]  ['楽しい'] 1
# [e_v4]"新しい趣味を見つけて、毎日が楽しい。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '彼氏とのデートで、素敵な時間を過ごした。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# デート	名詞,サ変接続,*,*,*,*,デート,デート,デート
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 素敵	名詞,形容動詞語幹,*,*,*,*,素敵,ステキ,ステキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ...
# 。	記号,句点,*,*,*,*,。,。,。
# text: 体調が良くなくて、会社を休んだ。
# [dict2]  ['良い'] 1
# [e_v4]"体調が良くなくて、会社を休んだ。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '好きな音楽を聴くと気分が明るくなる。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 音楽	名詞,一般,*,*,*,*,音楽,オンガク,オンガク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 聴く	動詞,自立,*,*,五段・カ行イ音便,基本形,聴く,キク,キク
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 明るく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,明るい,アカルク,アカルク
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きな音楽を聴くと気分が明るくなる。
# [dict1]  好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# [e_v4]"好きな音楽を聴くと気分が明るくなる。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '友達と映画を見に行ったけど、感動して泣いちゃった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 友達と映画を見に行った
# [dict1]  友達 1
# [e_v4]"友達と映画を見に行った":1*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# 感動	名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 泣い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,泣く,ナイ,ナイ
# ちゃっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,ちゃう,チャッ,チャッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、感動して泣いちゃった。
# [dict1]  感動 1
# [e_v4]"、感動して泣いちゃった。":1
# evaluated score: 0.5 , ans: 1
# ↑
# ↓
# ['p', '新しいプロジェクトが始まって、やる気満々。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# プロジェクト	名詞,一般,*,*,*,*,プロジェクト,プロジェクト,プロジェクト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# やる気	名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ
# 満々	名詞,一般,*,*,*,*,満々,マンマン,マンマン
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいプロジェクトが始まって、やる気満々。
# [dict1]  やる気 1
# [e_v4]"新しいプロジェクトが始まって、やる気満々。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '彼女との旅行が楽しみで、待ちきれない。']
# ======
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 旅行	名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 楽しみ	名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 待ち	動詞,自立,*,*,五段・タ行,連用形,待つ,マチ,マチ
# きれ	動詞,非自立,*,*,一段,未然形,きれる,キレ,キレ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼女との旅行が楽しみで、待ちきれない。
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# [e_v4]"彼女との旅行が楽しみで、待ちきれない。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '誕生日プレゼントをもらって、とても嬉しかった。']
# ======
# 誕生	名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# プレゼント	名詞,サ変接続,*,*,*,*,プレゼント,プレゼント,プレゼント
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# もらっ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 嬉しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,嬉しい,ウレシカッ,ウレシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 誕生日プレゼントをもらって、とても嬉しかった。
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"誕生日プレゼントをもらって、とても嬉しかった。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '好きなドラマの新シーズンが始まって嬉しい。']
# ======
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ドラマ	名詞,一般,*,*,*,*,ドラマ,ドラマ,ドラマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# シーズン	名詞,一般,*,*,*,*,シーズン,シーズン,シーズン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 好きなドラマの新シーズンが始まって嬉しい。
# [dict1]  好き 1
# [dict1]  新 0
# [dict2]  ['嬉しい'] 1
# [e_v4]"好きなドラマの新シーズンが始まって嬉しい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '久しぶりに休みが取れて、ゆっくり休むことができた。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 休み	名詞,一般,*,*,*,*,休み,ヤスミ,ヤスミ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 取れ	動詞,自立,*,*,一段,連用形,取れる,トレ,トレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 休む	動詞,自立,*,*,五段・マ行,基本形,休む,ヤスム,ヤスム
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
# [dict1]  久しぶり 0
# [dict1]  休み 0
# [e_v4]"久しぶりに休みが取れて、ゆっくり休むことができた。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '友達とのランチがとても楽しかった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ランチ	名詞,一般,*,*,*,*,ランチ,ランチ,ランチ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 楽しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とのランチがとても楽しかった。
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とのランチがとても楽しかった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['n', '彼女と喧嘩して、気まずい雰囲気になった。']
# ======
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 気まずい	形容詞,自立,*,*,形容詞・アウオ段,基本形,気まずい,キマズイ,キマズイ
# 雰囲気	名詞,一般,*,*,*,*,雰囲気,フンイキ,フンイキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼女と喧嘩して、気まずい雰囲気になった。
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# [e_v4]"彼女と喧嘩して、気まずい雰囲気になった。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '新しい本を読み始めて、止まらなくなった。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 読み	動詞,自立,*,*,五段・マ行,連用形,読む,ヨミ,ヨミ
# 始め	動詞,非自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 止まら	動詞,自立,*,*,五段・ラ行,未然形,止まる,トマラ,トマラ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しい本を読み始めて、止まらなくなった。
# [e_v4]"新しい本を読み始めて、止まらなくなった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['n', '仕事が忙しくてストレスが溜まっている。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 忙しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,忙しい,イソガシク,イソガシク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ストレス	名詞,一般,*,*,*,*,ストレス,ストレス,ストレス
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 溜まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,溜まる,タマッ,タマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事が忙しくてストレスが溜まっている。
# [dict1]  仕事 0
# [dict1]  ストレス -1
# [dict2]  ['忙しい'] -1
# [e_v4]"仕事が忙しくてストレスが溜まっている。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['n', 'ペットが病気になって心配でたまらない。早く元気になって。']
# ======
# ペット	名詞,一般,*,*,*,*,ペット,ペット,ペット
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 病気	名詞,サ変接続,*,*,*,*,病気,ビョウキ,ビョーキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 心配	名詞,サ変接続,*,*,*,*,心配,シンパイ,シンパイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# たまらない	形容詞,自立,*,*,形容詞・アウオ段,基本形,たまらない,タマラナイ,タマラナイ
# 。	記号,句点,*,*,*,*,。,。,。
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# 元気	名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 。	記号,句点,*,*,*,*,。,。,。
# text: ペットが病気になって心配でたまらない。早く元気になって。
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# [e_v4]"ペットが病気になって心配でたまらない。早く元気になって。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['n', '仕事でミスしてしまって、落ち込んでいる。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# ミス	名詞,サ変接続,*,*,*,*,ミス,ミス,ミス
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 落ち込ん	動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事でミスしてしまって、落ち込んでいる。
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# [e_v4]"仕事でミスしてしまって、落ち込んでいる。":-2
# evaluated score: -2 , ans: -1
# ↑
# ↓
# ['p', '彼氏とのデートで、素敵な時間を過ごした。']
# ======
# 彼氏	名詞,一般,*,*,*,*,彼氏,カレシ,カレシ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# デート	名詞,サ変接続,*,*,*,*,デート,デート,デート
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# 素敵	名詞,形容動詞語幹,*,*,*,*,素敵,ステキ,ステキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 過ごし	動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 彼氏とのデートで、素敵な時間を過ごした。
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# [e_v4]"彼氏とのデートで、素敵な時間を過ごした。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '猫が膝の上に乗ってきて、癒された。']
# ======
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 膝	名詞,一般,*,*,*,*,膝,ヒザ,ヒザ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 上	名詞,非自立,副詞可能,*,*,*,上,ウエ,ウエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 乗っ	動詞,自立,*,*,五段・ラ行,連用タ接続,乗る,ノッ,ノッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 癒さ	動詞,自立,*,*,五段・サ行,未然形,癒す,イヤサ,イヤサ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 猫が膝の上に乗ってきて、癒された。
# [dict2]  ['癒す'] 1
# [e_v4]"猫が膝の上に乗ってきて、癒された。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '友達とショッピングして、楽しい時間を過ごした。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# ショッピング	名詞,サ変接続,*,*,*,*,ショッピング,ショッピング,ショッピング
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 楽しい	形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 過ごし	動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とショッピングして、楽しい時間を過ごした。
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とショッピングして、楽しい時間を過ごした。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '友達とアウトドアに出かけて、楽しかった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# アウトドア	名詞,一般,*,*,*,*,アウトドア,アウトドア,アウトドア
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 出かけ	動詞,自立,*,*,一段,連用形,出かける,デカケ,デカケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 楽しかっ	形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達とアウトドアに出かけて、楽しかった。
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# [e_v4]"友達とアウトドアに出かけて、楽しかった。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '上司に認められて、やる気が出た。']
# ======
# 上司	名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 認め	動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# やる気	名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 上司に認められて、やる気が出た。
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# [e_v4]"上司に認められて、やる気が出た。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '新しいレシピを試してみたら、美味しくできた。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# レシピ	名詞,一般,*,*,*,*,レシピ,レシピ,レシピ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 試し	動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# 、	記号,読点,*,*,*,*,、,、,、
# 美味しく	形容詞,自立,*,*,形容詞・イ段,連用テ接続,美味しい,オイシク,オイシク
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいレシピを試してみたら、美味しくできた。
# [dict2]  ['美味しい'] 1
# [e_v4]"新しいレシピを試してみたら、美味しくできた。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '久しぶりに会った友達と話して、元気が出た。']
# ======
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 会っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,会う,アッ,アッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 話し	動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 元気	名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 久しぶりに会った友達と話して、元気が出た。
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# [e_v4]"久しぶりに会った友達と話して、元気が出た。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '昇進が決まって、とても嬉しい。']
# ======
# 昇進	名詞,サ変接続,*,*,*,*,昇進,ショウシン,ショーシン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 決まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,決まる,キマッ,キマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 嬉しい	形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 昇進が決まって、とても嬉しい。
# [dict1]  昇進 1
# [dict2]  ['嬉しい'] 1
# [e_v4]"昇進が決まって、とても嬉しい。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '仕事が終わって家に帰ると、ホッとする。']
# ======
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 家	名詞,一般,*,*,*,*,家,イエ,イエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 帰る	動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# ホッ	副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 仕事が終わって家に帰ると、ホッとする。
# [dict1]  仕事 0
# [e_v4]"仕事が終わって家に帰ると、ホッとする。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '映画館で見た映画がとても面白かった。']
# ======
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# 館	名詞,接尾,一般,*,*,*,館,カン,カン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# とても	副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ
# 面白かっ	形容詞,自立,*,*,形容詞・アウオ段,連用タ接続,面白い,オモシロカッ,オモシロカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 映画館で見た映画がとても面白かった。
# [dict2]  ['面白い'] 1
# [e_v4]"映画館で見た映画がとても面白かった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['n', '長時間の会議で疲れ果ててしまった。']
# ======
# 長時間	名詞,副詞可能,*,*,*,*,長時間,チョウジカン,チョージカン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 会議	名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# 果て	動詞,自立,*,*,一段,連用形,果てる,ハテ,ハテ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 長時間の会議で疲れ果ててしまった。
# [dict1]  長時間 0
# [dict2]  ['疲れる'] -1
# [e_v4]"長時間の会議で疲れ果ててしまった。":-1
# evaluated score: -1 , ans: -1
# ↑
# ↓
# ['p', '今日は誕生日で、たくさんのメッセージをもらった。']
# ======
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 誕生	名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー
# 日	名詞,接尾,一般,*,*,*,日,ビ,ビ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# たくさん	名詞,副詞可能,*,*,*,*,たくさん,タクサン,タクサン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# メッセージ	名詞,一般,*,*,*,*,メッセージ,メッセージ,メッセージ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# もらっ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 今日は誕生日で、たくさんのメッセージをもらった。
# [dict1]  誕生 1
# [dict1]  たくさん 0
# [e_v4]"今日は誕生日で、たくさんのメッセージをもらった。":1
# evaluated score: 1 , ans: 1
# ↑
# ↓
# ['p', '旅行の計画を立てているときが一番ワクワクする。']
# ======
# 旅行	名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 計画	名詞,サ変接続,*,*,*,*,計画,ケイカク,ケイカク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 立て	動詞,自立,*,*,一段,連用形,立てる,タテ,タテ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# とき	名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 一番	名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン
# ワクワク	副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
# text: 旅行の計画を立てているときが一番ワクワクする。
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# [e_v4]"旅行の計画を立てているときが一番ワクワクする。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['p', '試合に勝って、チーム全員で喜んだ。']
# ======
# 試合	名詞,サ変接続,*,*,*,*,試合,シアイ,シアイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 勝っ	動詞,自立,*,*,五段・タ行,連用タ接続,勝つ,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# チーム	名詞,一般,*,*,*,*,チーム,チーム,チーム
# 全員	名詞,一般,*,*,*,*,全員,ゼンイン,ゼンイン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 喜ん	動詞,自立,*,*,五段・バ行,連用タ接続,喜ぶ,ヨロコン,ヨロコン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 試合に勝って、チーム全員で喜んだ。
# [dict2]  ['勝つ'] 1
# [dict2]  ['喜ぶ'] 1
# [e_v4]"試合に勝って、チーム全員で喜んだ。":2
# evaluated score: 2 , ans: 1
# ↑
# ↓
# ['p', '猫と一緒に過ごす時間が一番の癒し。']
# ======
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 一緒	名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 過ごす	動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 一番	名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 癒し	動詞,自立,*,*,五段・サ行,連用形,癒す,イヤシ,イヤシ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 猫と一緒に過ごす時間が一番の癒し。
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# [e_v4]"猫と一緒に過ごす時間が一番の癒し。":3
# evaluated score: 3 , ans: 1
# ↑
# ↓
# ['e', '今日は特に何もない一日だったけど、それも悪くない。']
# ======
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 特に	副詞,一般,*,*,*,*,特に,トクニ,トクニ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# text: 今日は特に何もない一日だった
# [e_v4]"今日は特に何もない一日だった":0*"けど":-0.5
# 、	記号,読点,*,*,*,*,、,、,、
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 、それも悪くない。
# [dict2]  ['悪い'] -1
# [e_v4]"、それも悪くない。":1
# evaluated score: 1.0 , ans: 0
# ↑
# ↓
# ['p', '新しいゲームを始めて、ハマってしまった。']
# ======
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ゲーム	名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 始め	動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ハマっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 新しいゲームを始めて、ハマってしまった。
# [dict1]  ゲーム 0
# [e_v4]"新しいゲームを始めて、ハマってしまった。":0
# evaluated score: 0 , ans: 1
# ↑
# ↓
# ['p', '友達の結婚式に参加して、幸せな気持ちになった。']
# ======
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 結婚式	名詞,一般,*,*,*,*,結婚式,ケッコンシキ,ケッコンシキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 参加	名詞,サ変接続,*,*,*,*,参加,サンカ,サンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 幸せ	名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# text: 友達の結婚式に参加して、幸せな気持ちになった。
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# [e_v4]"友達の結婚式に参加して、幸せな気持ちになった。":3
# evaluated score: 3 , ans: 1
# ↑
# sum of number  of diffs: 23
