# %%
import sys
sys.path.append("../")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from janome.tokenizer import Tokenizer

# %%
from auto_polar.lib.predict_polarity import PolarEstimator, Dict1, Dict2
from auto_polar.lib import load_dictionary

# %%
dict1_df = pd.read_csv("../data/dictionary1.txt", sep="\t", header=None)
dict1_df.columns = ["word", "score", "description"]
dict1_df
# Out:
#        word score        description
# 0      ２，３日     e     〜である・になる（状態）客観
# 1       10%     e     〜である・になる（状態）客観
# 2      100%     e     〜である・になる（状態）客観
# 3       25%     e     〜である・になる（状態）客観
# 4       80%     e     〜である・になる（状態）客観
# ...     ...   ...                ...
# 13309     魏     e           〜に行く（場所）
# 13310  魑魅魍魎     n     〜である・になる（状態）客観
# 13311     鮑     e     〜である・になる（状態）客観
# 13312    鹹味     e  〜である・になる（評価・感情）主観
# 13313    麒麟     e     〜である・になる（状態）客観
#
# [13314 rows x 3 columns]

# %%
dict1_df["score"].value_counts()
# Out:
# score
# n       4958
# e       4954
# p       3352
# ?p?n      35
# ?e         4
# a          4
# o          3
# ?p         2
# ?p?e       1
# 　          1
# Name: count, dtype: int64

# %%
with open("../data/data.txt", "r", encoding="UTF-8") as f:
    inputs = f.readlines()

# %%
for token in Tokenizer().tokenize(inputs[1]):
    print(token)
    print(token.surface)
    print(token.base_form)
# Out:
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# 友達
# 友達
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# と
# と
# 映画	名詞,一般,*,*,*,*,映画,エイガ,エイガ
# 映画
# 映画
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# を
# を
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# 見
# 見る
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# に
# に
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# 行っ
# 行く
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# た
# た
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# けど
# けど
# 、	記号,読点,*,*,*,*,、,、,、
# 、
# 、
# 感動	名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー
# 感動
# 感動
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# し
# する
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# て
# て
# 泣い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,泣く,ナイ,ナイ
# 泣い
# 泣く
# ちゃっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,ちゃう,チャッ,チャッ
# ちゃっ
# ちゃう
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# た
# た
# 。	記号,句点,*,*,*,*,。,。,。
# 。
# 。

# %%
dict1 = load_dictionary.load_dict1("../data/dictionary1.txt")
dict2 = load_dictionary.load_dict2("../data/dictionary2.txt")

# %%
polar_estimator = PolarEstimator(Dict1(dict1), Dict2(dict2))

# %%
polar_estimator.estimate_v1(inputs[0], verbose=True)
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0

# %%
polar_estimator.estimate_v2(inputs[0], verbose=True)
# Out:
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
#
# [dict1]  雨 0
# [dict1]  気分 0
# [dict2]  ['落ち込む'] -1
# [dict2]  ['晴れる'] 1
# (0,
#  "text: 新しい仕事が始まって緊張するけど、頑張りたい。\n\n[dict1] 仕事 0\n[dict1] 緊張 -1\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n始まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n緊張\t名詞,サ変接続,*,*,*,*,緊張,キンチョウ,キンチョー\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\n、\t記号,読点,*,*,*,*,、,、,、\n頑張り\t動詞,自立,*,*,五段・ラ行,連用形,頑張る,ガンバリ,ガンバリ\n[dict2]found (['頑張る'], 1, '経験')\n[dict2] ['頑張る']1\nたい\t助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\n。\t記号,句点,*,*,*,*,。,。,。\n")

# %%
for text in inputs:
    print(polar_estimator.estimate_v1(text, verbose=True))
    print()
# Out:
# (0, 'text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。\n\n[dict1] 雨 0\n[dict1] 気分 0\n')
#
# (2, 'text: 友達と映画を見に行ったけど、感動して泣いちゃった。\n\n[dict1] 友達 1\n[dict1] 感動 1\n')
#
# (-1, 'text: 新しい仕事が始まって緊張するけど、頑張りたい。\n\n[dict1] 仕事 0\n[dict1] 緊張 -1\n')
#
# (2, 'text: 美味しいケーキを食べて、幸せな気持ちになった。\n\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n')
#
# (-1, 'text: ペットが病気になって心配でたまらない。早く元気になって。\n\n[dict1] ペット 0\n[dict1] 病気 -1\n[dict1] 心配 -1\n[dict1] 元気 1\n')
#
# (1, 'text: 家族と一緒に過ごす時間がとても楽しかった。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n')
#
# (-1, 'text: 仕事でミスをして上司に叱られてしまった。反省しないと。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n[dict1] 反省 0\n')
#
# (2, 'text: 旅行の計画を立てているときが一番ワクワクする。\n\n[dict1] 旅行 1\n[dict1] 一番 1\n')
#
# (2, 'text: 久しぶりに会った友達と話して、元気が出た。\n\n[dict1] 久しぶり 0\n[dict1] 友達 1\n[dict1] 元気 1\n')
#
# (0, 'text: 電車が遅れてイライラするけど、仕方がない。\n\n')
#
# (0, 'text: 新しい趣味を見つけて、毎日が楽しい。\n\n[dict1] 趣味 0\n')
#
# (3, 'text: 彼氏とのデートで素敵なレストランに行って幸せ。\n\n[dict1] デート 1\n[dict1] 素敵 1\n[dict1] 幸せ 1\n')
#
# (0, 'text: 今日も一日がんばった。自分を褒めたい気分。\n\n[dict1] 自分 0\n[dict1] 気分 0\n')
#
# (0, 'text: 雨の日はどうしても気分が沈んでしまう。\n\n[dict1] 雨 0\n[dict1] 気分 0\n')
#
# (1, 'text: 大好きな音楽を聴くと気分が明るくなる。\n\n[dict1] 大好き 1\n[dict1] 気分 0\n')
#
# (-1, 'text: 試験の結果が悪くて、落ち込んでしまった。\n\n[dict1] 試験 -1\n')
#
# (1, 'text: 彼女からのサプライズプレゼントに感動した。\n\n[dict1] 感動 1\n')
#
# (0, 'text: 久しぶりに休みが取れて、ゆっくり休むことができた。\n\n[dict1] 久しぶり 0\n[dict1] 休み 0\n')
#
# (-1, 'text: 仕事が忙しくてストレスが溜まっている。\n\n[dict1] 仕事 0\n[dict1] ストレス -1\n')
#
# (1, 'text: 友達と喧嘩してしまって、悲しい気持ちになった。\n\n[dict1] 友達 1\n[dict1] 喧嘩 -1\n[dict1] 気持ち 1\n')
#
# (0, 'text: 新しい洋服を買って、気分が上がった。\n\n[dict1] 気分 0\n')
#
# (2, 'text: 猫と一緒に過ごす時間が一番の癒し。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n[dict1] 一番 1\n')
#
# (0, 'text: 今日は特に何もない一日だったけど、それも悪くない。\n\n')
#
# (1, 'text: 親友と久しぶりに再会して、楽しい時間を過ごした。\n\n[dict1] 親友 1\n[dict1] 久しぶり 0\n[dict1] 再会 0\n[dict1] 時間 0\n')
#
# (1, 'text: 好きなドラマの新シーズンが始まって嬉しい。\n\n[dict1] 好き 1\n[dict1] 新 0\n')
#
# (-1, 'text: 失恋してからなかなか立ち直れない。\n\n[dict1] 失恋 -1\n')
#
# (1, 'text: 仕事のプレゼンがうまくいって、自信がついた。\n\n[dict1] 仕事 0\n[dict1] 自信 1\n')
#
# (0, 'text: 朝から体調が悪くて、一日中寝ていた。\n\n[dict1] 朝 0\n[dict1] 中 0\n')
#
# (2, 'text: 散歩中に見た夕日がとても綺麗だった。\n\n[dict1] 散歩 1\n[dict1] 中 0\n[dict1] 綺麗 1\n')
#
# (0, 'text: 新しいレシピを試してみたら、美味しくできた。\n\n')
#
# (2, 'text: 同僚に助けられて、感謝の気持ちでいっぱい。\n\n[dict1] 感謝 1\n[dict1] 気持ち 1\n[dict1] いっぱい 0\n')
#
# (0, 'text: 彼氏との電話が楽しくて、夜更かししてしまった。\n\n')
#
# (0, 'text: スポーツジムで体を動かして、スッキリした。\n\n[dict1] スポーツ 0\n')
#
# (0, 'text: 雨上がりの虹を見て、心が洗われるようだった。\n\n')
#
# (0, 'text: 試合に勝って、チーム全員で喜んだ。\n\n')
#
# (1, 'text: 今日は誕生日で、たくさんのメッセージをもらった。\n\n[dict1] 誕生 1\n[dict1] たくさん 0\n')
#
# (-1, 'text: ミスをしてしまって、上司に怒られて落ち込んだ。\n\n[dict1] ミス -1\n')
#
# (0, 'text: 久しぶりに母の手料理を食べて、懐かしい気分になった。\n\n[dict1] 久しぶり 0\n[dict1] 気分 0\n')
#
# (0, 'text: 面白い本を見つけて、読みふけってしまった。\n\n')
#
# (3, 'text: 友達の結婚式に参加して、幸せな気持ちになった。\n\n[dict1] 友達 1\n[dict1] 参加 0\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n')
#
# (-1, 'text: 風邪をひいてしまって、ずっと寝ている。\n\n[dict1] 風邪 -1\n')
#
# (0, 'text: 新しいゲームを始めて、ハマってしまった。\n\n[dict1] ゲーム 0\n')
#
# (0, 'text: 猫が膝の上に乗ってきて、癒された。\n\n')
#
# (0, 'text: 長い一日が終わって、ほっと一息ついた。\n\n')
#
# (1, 'text: 昇進が決まって、とても嬉しい。\n\n[dict1] 昇進 1\n')
#
# (2, 'text: お風呂に入ってリラックスする時間が好き。\n\n[dict1] リラックス 1\n[dict1] 時間 0\n[dict1] 好き 1\n')
#
# (1, 'text: 友達とカフェでおしゃべりして、楽しい時間を過ごした。\n\n[dict1] 友達 1\n[dict1] 時間 0\n')
#
# (1, 'text: 自分の作品が認められて、嬉しい気持ちになった。\n\n[dict1] 自分 0\n[dict1] 気持ち 1\n')
#
# (1, 'text: 会議が長引いて疲れたけど、達成感がある。\n\n[dict1] 達成 1\n')
#
# (2, 'text: 彼女との旅行が楽しみで、待ちきれない。\n\n[dict1] 旅行 1\n[dict1] 楽しみ 1\n')
#
# (0, 'text: 仕事が終わって家に帰ると、ホッとする。\n\n[dict1] 仕事 0\n')
#
# (2, 'text: 好きなバンドのライブに行って、最高の夜だった。\n\n[dict1] 好き 1\n[dict1] 最高 1\n')
#
# (0, 'text: 忙しい日々が続いていて、少し疲れている。\n\n')
#
# (0, 'text: 彼氏からのサプライズに驚いて、嬉しかった。\n\n')
#
# (-1, 'text: 親友と大喧嘩してしまって、後悔している。\n\n[dict1] 親友 1\n[dict1] 喧嘩 -1\n[dict1] 後悔 -1\n')
#
# (2, 'text: 美味しいラーメンを食べて、幸せな気持ちになった。\n\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n')
#
# (0, 'text: 風が強くて、外に出るのが億劫だった。\n\n')
#
# (1, 'text: 新しいプロジェクトが始まって、やる気満々。\n\n[dict1] やる気 1\n')
#
# (0, 'text: 長時間の会議で疲れ果ててしまった。\n\n[dict1] 長時間 0\n')
#
# (1, 'text: 久しぶりに海に行って、リフレッシュできた。\n\n[dict1] 久しぶり 0\n[dict1] リフレッシュ 1\n')
#
# (-3, 'text: 試験勉強が大変で、ストレスが溜まっている。\n\n[dict1] 試験 -1\n[dict1] 大変 -1\n[dict1] ストレス -1\n')
#
# (1, 'text: 友達の赤ちゃんが生まれて、とても嬉しい。\n\n[dict1] 友達 1\n')
#
# (1, 'text: プレゼントをもらって、心が温まった。\n\n[dict1] プレゼント 1\n')
#
# (2, 'text: 好きなアーティストのコンサートが楽しみ。\n\n[dict1] 好き 1\n[dict1] アーティスト 0\n[dict1] 楽しみ 1\n')
#
# (0, 'text: 雨の日は読書に限ると、改めて感じた。\n\n[dict1] 雨 0\n')
#
# (0, 'text: 体調が良くなくて、会社を休んだ。\n\n')
#
# (0, 'text: 新しい料理に挑戦して、上手くできた。\n\n[dict1] 料理 0\n[dict1] 挑戦 0\n')
#
# (0, 'text: 映画館で見た映画がとても面白かった。\n\n')
#
# (0, 'text: 彼氏とケンカして、悲しい気持ちになった。\n\n[dict1] ケンカ -1\n[dict1] 気持ち 1\n')
#
# (1, 'text: 友達とアウトドアに出かけて、楽しかった。\n\n[dict1] 友達 1\n[dict1] アウトドア 0\n')
#
# (1, 'text: 上司に認められて、やる気が出た。\n\n[dict1] やる気 1\n')
#
# (2, 'text: 誕生日プレゼントをもらって、とても嬉しかった。\n\n[dict1] 誕生 1\n[dict1] プレゼント 1\n')
#
# (1, 'text: 雪が降っていて、外に出るのが楽しみ。\n\n[dict1] 雪 0\n[dict1] 楽しみ 1\n')
#
# (1, 'text: 新しいカフェを見つけて、友達と行ってみた。\n\n[dict1] 友達 1\n')
#
# (-1, 'text: 仕事でミスしてしまって、落ち込んでいる。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n')
#
# (1, 'text: 好きなアニメの新作が出て、ワクワクしている。\n\n[dict1] 好き 1\n[dict1] 新作 0\n')
#
# (-1, 'text: 体調が悪くて、早退した。\n\n[dict1] 早退 -1\n')
#
# (4, 'text: 友達と旅行に行って、最高の思い出ができた。\n\n[dict1] 友達 1\n[dict1] 旅行 1\n[dict1] 最高 1\n[dict1] 思い出 1\n')
#
# (0, 'text: 疲れているのに、寝付けない夜が続いている。\n\n')
#
# (0, 'text: 新しい靴を買って、ウキウキしている。\n\n')
#
# (2, 'text: 恋人との記念日を祝って、幸せな時間を過ごした。\n\n[dict1] 恋人 1\n[dict1] 記念 0\n[dict1] 幸せ 1\n[dict1] 時間 0\n')
#
# (1, 'text: 上司に褒められて、自信がついた。\n\n[dict1] 自信 1\n')
#
# (2, 'text: 雨の日の静けさが好きで、落ち着く。\n\n[dict1] 雨 0\n[dict1] 静けさ 1\n[dict1] 好き 1\n')
#
# (1, 'text: 友達とのランチがとても楽しかった。\n\n[dict1] 友達 1\n')
#
# (2, 'text: 仕事で成果を出して、達成感がある。\n\n[dict1] 仕事 0\n[dict1] 成果 1\n[dict1] 達成 1\n')
#
# (1, 'text: お風呂にゆっくり浸かって、リラックスした。\n\n[dict1] リラックス 1\n')
#
# (0, 'text: 彼女と喧嘩して、気まずい雰囲気になった。\n\n[dict1] 喧嘩 -1\n[dict1] 雰囲気 1\n')
#
# (0, 'text: 新しい本を読み始めて、止まらなくなった。\n\n')
#
# (2, 'text: 大好きなカフェで、ゆっくり過ごす時間が幸せ。\n\n[dict1] 大好き 1\n[dict1] 時間 0\n[dict1] 幸せ 1\n')
#
# (3, 'text: 友達の誕生日を祝って、一緒に楽しんだ。\n\n[dict1] 友達 1\n[dict1] 誕生 1\n[dict1] 一緒 1\n')
#
# (0, 'text: 仕事が忙しくて、なかなか休めない。\n\n[dict1] 仕事 0\n')
#
# (2, 'text: 好きな映画を見て、リフレッシュできた。\n\n[dict1] 好き 1\n[dict1] リフレッシュ 1\n')
#
# (0, 'text: 新しい趣味を見つけて、毎日が楽しい。\n\n[dict1] 趣味 0\n')
#
# (2, 'text: 彼氏とのデートで、素敵な時間を過ごした。\n\n[dict1] デート 1\n[dict1] 素敵 1\n[dict1] 時間 0\n')
#
# (-1, 'text: 雨が降っていて、外に出るのが憂鬱。\n\n[dict1] 雨 0\n[dict1] 憂鬱 -1\n')
#
# (3, 'text: 友達と一緒にいると、元気が出る。\n\n[dict1] 友達 1\n[dict1] 一緒 1\n[dict1] 元気 1\n')
#
# (-1, 'text: 仕事でミスをして、上司に叱られた。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n')
#
# (0, 'text: 新しいレストランで、美味しい料理を楽しんだ。\n\n[dict1] 料理 0\n')
#
# (0, 'text: 体調が悪くて、一日中寝ていた。\n\n[dict1] 中 0\n')
#
# (1, 'text: 友達とショッピングして、楽しい時間を過ごした。\n\n[dict1] 友達 1\n[dict1] 時間 0\n')
#
# (1, 'text: 彼氏からのサプライズに感動した。\n\n[dict1] 感動 1\n')
#
# (0, 'text: 忙しい日々が続いていて、少し疲れている。\n\n')
#
# (2, 'text: 猫と一緒に過ごす時間が一番の癒し。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n[dict1] 一番 1\n')
#
# (0, 'text: 雨の日はどうしても気分が沈んでしまう。\n\n[dict1] 雨 0\n[dict1] 気分 0\n')
#
# (-1, 'text: 新しい仕事が始まって、緊張するけど頑張りたい。\n\n[dict1] 仕事 0\n[dict1] 緊張 -1\n')
#
# (1, 'text: 友達の赤ちゃんが生まれて、とても嬉しい。\n\n[dict1] 友達 1\n')
#
# (0, 'text: 彼氏との電話が楽しくて、夜更かししてしまった。\n\n')
#
# (2, 'text: 仕事で成果を出して、達成感がある。\n\n[dict1] 仕事 0\n[dict1] 成果 1\n[dict1] 達成 1\n')
#
# (0, 'text: 体調が良くなくて、会社を休んだ。\n\n')
#
# (1, 'text: 好きな音楽を聴くと気分が明るくなる。\n\n[dict1] 好き 1\n[dict1] 気分 0\n')
#
# (2, 'text: 友達と映画を見に行ったけど、感動して泣いちゃった。\n\n[dict1] 友達 1\n[dict1] 感動 1\n')
#
# (1, 'text: 新しいプロジェクトが始まって、やる気満々。\n\n[dict1] やる気 1\n')
#
# (2, 'text: 彼女との旅行が楽しみで、待ちきれない。\n\n[dict1] 旅行 1\n[dict1] 楽しみ 1\n')
#
# (2, 'text: 誕生日プレゼントをもらって、とても嬉しかった。\n\n[dict1] 誕生 1\n[dict1] プレゼント 1\n')
#
# (1, 'text: 好きなドラマの新シーズンが始まって嬉しい。\n\n[dict1] 好き 1\n[dict1] 新 0\n')
#
# (0, 'text: 久しぶりに休みが取れて、ゆっくり休むことができた。\n\n[dict1] 久しぶり 0\n[dict1] 休み 0\n')
#
# (1, 'text: 友達とのランチがとても楽しかった。\n\n[dict1] 友達 1\n')
#
# (0, 'text: 彼女と喧嘩して、気まずい雰囲気になった。\n\n[dict1] 喧嘩 -1\n[dict1] 雰囲気 1\n')
#
# (0, 'text: 新しい本を読み始めて、止まらなくなった。\n\n')
#
# (-1, 'text: 仕事が忙しくてストレスが溜まっている。\n\n[dict1] 仕事 0\n[dict1] ストレス -1\n')
#
# (-1, 'text: ペットが病気になって心配でたまらない。早く元気になって。\n\n[dict1] ペット 0\n[dict1] 病気 -1\n[dict1] 心配 -1\n[dict1] 元気 1\n')
#
# (-1, 'text: 仕事でミスしてしまって、落ち込んでいる。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n')
#
# (2, 'text: 彼氏とのデートで、素敵な時間を過ごした。\n\n[dict1] デート 1\n[dict1] 素敵 1\n[dict1] 時間 0\n')
#
# (0, 'text: 猫が膝の上に乗ってきて、癒された。\n\n')
#
# (1, 'text: 友達とショッピングして、楽しい時間を過ごした。\n\n[dict1] 友達 1\n[dict1] 時間 0\n')
#
# (1, 'text: 友達とアウトドアに出かけて、楽しかった。\n\n[dict1] 友達 1\n[dict1] アウトドア 0\n')
#
# (1, 'text: 上司に認められて、やる気が出た。\n\n[dict1] やる気 1\n')
#
# (0, 'text: 新しいレシピを試してみたら、美味しくできた。\n\n')
#
# (2, 'text: 久しぶりに会った友達と話して、元気が出た。\n\n[dict1] 久しぶり 0\n[dict1] 友達 1\n[dict1] 元気 1\n')
#
# (1, 'text: 昇進が決まって、とても嬉しい。\n\n[dict1] 昇進 1\n')
#
# (0, 'text: 仕事が終わって家に帰ると、ホッとする。\n\n[dict1] 仕事 0\n')
#
# (0, 'text: 映画館で見た映画がとても面白かった。\n\n')
#
# (0, 'text: 長時間の会議で疲れ果ててしまった。\n\n[dict1] 長時間 0\n')
#
# (1, 'text: 今日は誕生日で、たくさんのメッセージをもらった。\n\n[dict1] 誕生 1\n[dict1] たくさん 0\n')
#
# (2, 'text: 旅行の計画を立てているときが一番ワクワクする。\n\n[dict1] 旅行 1\n[dict1] 一番 1\n')
#
# (0, 'text: 試合に勝って、チーム全員で喜んだ。\n\n')
#
# (2, 'text: 猫と一緒に過ごす時間が一番の癒し。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n[dict1] 一番 1\n')
#
# (0, 'text: 今日は特に何もない一日だったけど、それも悪くない。\n\n')
#
# (0, 'text: 新しいゲームを始めて、ハマってしまった。\n\n[dict1] ゲーム 0\n')
#
# (3, 'text: 友達の結婚式に参加して、幸せな気持ちになった。```\n\n[dict1] 友達 1\n[dict1] 参加 0\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n')

# %%
for text in inputs:
    print(polar_estimator.estimate_v2(text, verbose=True))
    print()
# Out:
# (1, "text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。\n\n[dict1] 雨 0\n[dict1] 気分 0\n雨\t名詞,一般,*,*,*,*,雨,アメ,アメ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n降っ\t動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ\nてる\t動詞,非自立,*,*,一段,基本形,てる,テル,テル\nから\t助詞,接続助詞,*,*,*,*,から,カラ,カラ\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n落ち込む\t動詞,自立,*,*,五段・マ行,基本形,落ち込む,オチコム,オチコム\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n早く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク\n晴れ\t動詞,自立,*,*,一段,連用形,晴れる,ハレ,ハレ\n[dict2]found (['晴れる'], 1, '経験')\n[dict2] ['晴れる']1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nほしい\t形容詞,非自立,*,*,形容詞・イ段,基本形,ほしい,ホシイ,ホシイ\nな\t助詞,終助詞,*,*,*,*,な,ナ,ナ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# [dict1]  雨 0
# [dict1]  気分 0
# [dict2]  ['落ち込む'] -1
# [dict2]  ['晴れる'] 1
# 0
#
# (0, "text: 新しい仕事が始まって緊張するけど、頑張りたい。\n\n[dict1] 仕事 0\n[dict1] 緊張 -1\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n始まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n緊張\t名詞,サ変接続,*,*,*,*,緊張,キンチョウ,キンチョー\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\n、\t記号,読点,*,*,*,*,、,、,、\n頑張り\t動詞,自立,*,*,五段・ラ行,連用形,頑張る,ガンバリ,ガンバリ\n[dict2]found (['頑張る'], 1, '経験')\n[dict2] ['頑張る']1\nたい\t助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 美味しいケーキを食べて、幸せな気持ちになった。\n\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n美味しい\t形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ\n[dict2]found (['美味しい'], 1, '評価')\n[dict2] ['美味しい']1\nケーキ\t名詞,一般,*,*,*,*,ケーキ,ケーキ,ケーキ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n食べ\t動詞,自立,*,*,一段,連用形,食べる,タベ,タベ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n幸せ\t名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, 'text: ペットが病気になって心配でたまらない。早く元気になって。\n\n[dict1] ペット 0\n[dict1] 病気 -1\n[dict1] 心配 -1\n[dict1] 元気 1\nペット\t名詞,一般,*,*,*,*,ペット,ペット,ペット\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n病気\t名詞,サ変接続,*,*,*,*,病気,ビョウキ,ビョーキ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n心配\t名詞,サ変接続,*,*,*,*,心配,シンパイ,シンパイ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nたまらない\t形容詞,自立,*,*,形容詞・アウオ段,基本形,たまらない,タマラナイ,タマラナイ\n。\t記号,句点,*,*,*,*,。,。,。\n早く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク\n元気\t名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, "text: 家族と一緒に過ごす時間がとても楽しかった。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n家族\t名詞,一般,*,*,*,*,家族,カゾク,カゾク\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\n一緒\t名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n過ごす\t動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n楽しかっ\t形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 仕事でミスをして上司に叱られてしまった。反省しないと。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n[dict1] 反省 0\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nミス\t名詞,サ変接続,*,*,*,*,ミス,ミス,ミス\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n上司\t名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n叱ら\t動詞,自立,*,*,五段・ラ行,未然形,叱る,シカラ,シカラ\nれ\t動詞,接尾,*,*,一段,連用形,れる,レ,レ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n反省\t名詞,サ変接続,*,*,*,*,反省,ハンセイ,ハンセイ\nし\t動詞,自立,*,*,サ変・スル,未然形,する,シ,シ\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\nと\t助詞,接続助詞,*,*,*,*,と,ト,ト\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, 'text: 旅行の計画を立てているときが一番ワクワクする。\n\n[dict1] 旅行 1\n[dict1] 一番 1\n旅行\t名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n計画\t名詞,サ変接続,*,*,*,*,計画,ケイカク,ケイカク\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n立て\t動詞,自立,*,*,一段,連用形,立てる,タテ,タテ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\nとき\t名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n一番\t名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン\nワクワク\t副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, "text: 久しぶりに会った友達と話して、元気が出た。\n\n[dict1] 久しぶり 0\n[dict1] 友達 1\n[dict1] 元気 1\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n会っ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,会う,アッ,アッ\n[dict2]found (['会う', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['会う', 'こと', 'は', 'できる'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['会う', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['会う', 'こと', 'は', 'できる'], 1, '評価')\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,格助詞,引用,*,*,*,と,ト,ト\n話し\t動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ\n[dict2]found (['話す', '上手', 'だ'], 1, '評価')\n[dict2]found (['話す', '上手', 'です'], 1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['話す', '上手', 'だ'], 1, '評価')\n[dict2]found (['話す', '上手', 'です'], 1, '評価')\n、\t記号,読点,*,*,*,*,、,、,、\n元気\t名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# (1, "text: 新しい趣味を見つけて、毎日が楽しい。\n\n[dict1] 趣味 0\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\n趣味\t名詞,一般,*,*,*,*,趣味,シュミ,シュミ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n見つけ\t動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n毎日\t名詞,固有名詞,組織,*,*,*,毎日,マイニチ,マイニチ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n楽しい\t形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 彼氏とのデートで素敵なレストランに行って幸せ。\n\n[dict1] デート 1\n[dict1] 素敵 1\n[dict1] 幸せ 1\n彼氏\t名詞,一般,*,*,*,*,彼氏,カレシ,カレシ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nデート\t名詞,サ変接続,*,*,*,*,デート,デート,デート\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n素敵\t名詞,形容動詞語幹,*,*,*,*,素敵,ステキ,ステキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nレストラン\t名詞,一般,*,*,*,*,レストラン,レストラン,レストラン\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n行っ\t動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n幸せ\t名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 今日も一日がんばった。自分を褒めたい気分。\n\n[dict1] 自分 0\n[dict1] 気分 0\n今日\t名詞,副詞可能,*,*,*,*,今日,キョウ,キョー\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n日\t名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\nがんばっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,がんばる,ガンバッ,ガンバッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n自分\t名詞,一般,*,*,*,*,自分,ジブン,ジブン\n[dict2]found (['自分', '向き'], 1, '評価')\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n[dict2]found (['自分', '向き'], 1, '評価')\n褒め\t動詞,自立,*,*,一段,連用形,褒める,ホメ,ホメ\nたい\t助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n")
#
# (0, "text: 雨の日はどうしても気分が沈んでしまう。\n\n[dict1] 雨 0\n[dict1] 気分 0\n雨\t名詞,一般,*,*,*,*,雨,アメ,アメ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n日\t名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\nどうしても\t副詞,一般,*,*,*,*,どうしても,ドウシテモ,ドーシテモ\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n沈ん\t動詞,自立,*,*,五段・マ行,連用タ接続,沈む,シズン,シズン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nで\t助詞,接続助詞,*,*,*,*,で,デ,デ\nしまう\t動詞,非自立,*,*,五段・ワ行促音便,基本形,しまう,シマウ,シマウ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 大好きな音楽を聴くと気分が明るくなる。\n\n[dict1] 大好き 1\n[dict1] 気分 0\n大好き\t名詞,形容動詞語幹,*,*,*,*,大好き,ダイスキ,ダイスキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n音楽\t名詞,一般,*,*,*,*,音楽,オンガク,オンガク\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n聴く\t動詞,自立,*,*,五段・カ行イ音便,基本形,聴く,キク,キク\nと\t助詞,接続助詞,*,*,*,*,と,ト,ト\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n明るく\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,明るい,アカルク,アカルク\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nなる\t動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# 3
#
# (1, "text: 彼女からのサプライズプレゼントに感動した。\n\n[dict1] 感動 1\n彼女\t名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ\nから\t助詞,格助詞,一般,*,*,*,から,カラ,カラ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nサプライズプレゼント\t名詞,一般,*,*,*,*,サプライズプレゼント,*,*\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n感動\t名詞,サ変接続,*,*,*,*,感動,カンドウ,カンドー\n[dict2]found (['感動', '的', 'だ'], 1, '評価')\n[dict2]found (['感動', '的', 'です'], 1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\n[dict2]found (['感動', '的', 'だ'], 1, '評価')\n[dict2]found (['感動', '的', 'です'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 久しぶりに休みが取れて、ゆっくり休むことができた。\n\n[dict1] 久しぶり 0\n[dict1] 休み 0\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n休み\t名詞,一般,*,*,*,*,休み,ヤスミ,ヤスミ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n取れ\t動詞,自立,*,*,一段,連用形,取れる,トレ,トレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nゆっくり\t副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ\n休む\t動詞,自立,*,*,五段・マ行,基本形,休む,ヤスム,ヤスム\nこと\t名詞,非自立,一般,*,*,*,こと,コト,コト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nでき\t動詞,自立,*,*,一段,連用形,できる,デキ,デキ\n[dict2]found (['できる', '損なう'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['できる', '損なう'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-2, "text: 仕事が忙しくてストレスが溜まっている。\n\n[dict1] 仕事 0\n[dict1] ストレス -1\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n忙しく\t形容詞,自立,*,*,形容詞・イ段,連用テ接続,忙しい,イソガシク,イソガシク\n[dict2]found (['忙しい'], -1, '評価')\n[dict2] ['忙しい']-1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nストレス\t名詞,一般,*,*,*,*,ストレス,ストレス,ストレス\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\n溜まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,溜まる,タマッ,タマッ\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 友達と喧嘩してしまって、悲しい気持ちになった。\n\n[dict1] 友達 1\n[dict1] 喧嘩 -1\n[dict1] 気持ち 1\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\n喧嘩\t名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n悲しい\t形容詞,自立,*,*,形容詞・イ段,基本形,悲しい,カナシイ,カナシイ\n[dict2]found (['悲しい'], -1, '評価')\n[dict2] ['悲しい']-1\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 新しい洋服を買って、気分が上がった。\n\n[dict1] 気分 0\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\n洋服\t名詞,一般,*,*,*,*,洋服,ヨウフク,ヨーフク\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n買っ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\n上がっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,上がる,アガッ,アガッ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 猫と一緒に過ごす時間が一番の癒し。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n[dict1] 一番 1\n猫\t名詞,一般,*,*,*,*,猫,ネコ,ネコ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\n一緒\t名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n過ごす\t動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n一番\t名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n癒し\t動詞,自立,*,*,五段・サ行,連用形,癒す,イヤシ,イヤシ\n[dict2]found (['癒す'], 1, '評価')\n[dict2] ['癒す']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 今日は特に何もない一日だったけど、それも悪くない。\n\n今日\t名詞,副詞可能,*,*,*,*,今日,キョウ,キョー\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n特に\t副詞,一般,*,*,*,*,特に,トクニ,トクニ\n何\t名詞,代名詞,一般,*,*,*,何,ナニ,ナニ\n[dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')\n[dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\n[dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')\n[dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')\nない\t形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n日\t名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\n、\t記号,読点,*,*,*,*,、,、,、\nそれ\t名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\n悪く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク\n[dict2]found (['悪い'], -1, '評価')\n[dict2] ['悪い']-1\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 親友と久しぶりに再会して、楽しい時間を過ごした。\n\n[dict1] 親友 1\n[dict1] 久しぶり 0\n[dict1] 再会 0\n[dict1] 時間 0\n親友\t名詞,一般,*,*,*,*,親友,シンユウ,シンユー\nと\t助詞,並立助詞,*,*,*,*,と,ト,ト\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n再会\t名詞,サ変接続,*,*,*,*,再会,サイカイ,サイカイ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n楽しい\t形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n過ごし\t動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 好きなドラマの新シーズンが始まって嬉しい。\n\n[dict1] 好き 1\n[dict1] 新 0\n好き\t名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nドラマ\t名詞,一般,*,*,*,*,ドラマ,ドラマ,ドラマ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n新\t接頭詞,名詞接続,*,*,*,*,新,シン,シン\nシーズン\t名詞,一般,*,*,*,*,シーズン,シーズン,シーズン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n始まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n嬉しい\t形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, 'text: 失恋してからなかなか立ち直れない。\n\n[dict1] 失恋 -1\n失恋\t名詞,サ変接続,*,*,*,*,失恋,シツレン,シツレン\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nから\t助詞,格助詞,一般,*,*,*,から,カラ,カラ\nなかなか\t副詞,助詞類接続,*,*,*,*,なかなか,ナカナカ,ナカナカ\n立ち直れ\t動詞,自立,*,*,一段,未然形,立ち直れる,タチナオレ,タチナオレ\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, "text: 仕事のプレゼンがうまくいって、自信がついた。\n\n[dict1] 仕事 0\n[dict1] 自信 1\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nプレゼン\t名詞,サ変接続,*,*,*,*,プレゼン,プレゼン,プレゼン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nうまく\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,うまい,ウマク,ウマク\n[dict2]found (['うまい'], 1, '評価')\n[dict2] ['うまい']1\nいっ\t動詞,自立,*,*,五段・カ行促音便,連用タ接続,いく,イッ,イッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n自信\t名詞,一般,*,*,*,*,自信,ジシン,ジシン\n[dict2]found (['自信', 'が', 'ない'], -1, '経験')\n[dict2]found (['自信', 'が', 'ある'], 1, '経験')\n[dict2]found (['自信', 'たっぷり', 'だ'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'です'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'と'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'の'], 1, '評価')\n[dict2]found (['自信', '作'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['自信', 'が', 'ない'], -1, '経験')\n[dict2]found (['自信', 'が', 'ある'], 1, '経験')\n[dict2]found (['自信', 'たっぷり', 'だ'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'です'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'と'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'の'], 1, '評価')\n[dict2]found (['自信', '作'], 1, '評価')\nつい\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ\n[dict2]found (['自信', 'が', 'ない'], -1, '経験')\n[dict2]found (['自信', 'が', 'ある'], 1, '経験')\n[dict2]found (['自信', 'たっぷり', 'だ'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'です'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'と'], 1, '評価')\n[dict2]found (['自信', 'たっぷり', 'の'], 1, '評価')\n[dict2]found (['自信', '作'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 朝から体調が悪くて、一日中寝ていた。\n\n[dict1] 朝 0\n[dict1] 中 0\n朝\t名詞,副詞可能,*,*,*,*,朝,アサ,アサ\nから\t助詞,格助詞,一般,*,*,*,から,カラ,カラ\n体調\t名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n悪く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク\n[dict2]found (['悪い'], -1, '評価')\n[dict2] ['悪い']-1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n日\t名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n中\t名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー\n寝\t動詞,自立,*,*,一段,連用形,寝る,ネ,ネ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nい\t動詞,非自立,*,*,一段,連用形,いる,イ,イ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 散歩中に見た夕日がとても綺麗だった。\n\n[dict1] 散歩 1\n[dict1] 中 0\n[dict1] 綺麗 1\n散歩\t名詞,サ変接続,*,*,*,*,散歩,サンポ,サンポ\n中\t名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n見\t動詞,自立,*,*,一段,連用形,見る,ミ,ミ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\n夕日\t名詞,一般,*,*,*,*,夕日,ユウヒ,ユーヒ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n綺麗\t名詞,形容動詞語幹,*,*,*,*,綺麗,キレイ,キレイ\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# [dict1]  大好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# 2
#
# (2, "text: 同僚に助けられて、感謝の気持ちでいっぱい。\n\n[dict1] 感謝 1\n[dict1] 気持ち 1\n[dict1] いっぱい 0\n同僚\t名詞,一般,*,*,*,*,同僚,ドウリョウ,ドーリョー\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n助け\t動詞,自立,*,*,一段,未然形,助ける,タスケ,タスケ\nられ\t動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n感謝\t名詞,サ変接続,*,*,*,*,感謝,カンシャ,カンシャ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nいっぱい\t副詞,一般,*,*,*,*,いっぱい,イッパイ,イッパイ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 彼氏との電話が楽しくて、夜更かししてしまった。\n\n彼氏\t名詞,一般,*,*,*,*,彼氏,カレシ,カレシ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n電話\t名詞,サ変接続,*,*,*,*,電話,デンワ,デンワ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n楽しく\t形容詞,自立,*,*,形容詞・イ段,連用テ接続,楽しい,タノシク,タノシク\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n夜\t名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル\n更かし\t動詞,自立,*,*,五段・サ行,連用形,更かす,フカシ,フカシ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: スポーツジムで体を動かして、スッキリした。\n\n[dict1] スポーツ 0\nスポーツ\t名詞,一般,*,*,*,*,スポーツ,スポーツ,スポーツ\nジム\t名詞,一般,*,*,*,*,ジム,ジム,ジム\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n体\t名詞,一般,*,*,*,*,体,カラダ,カラダ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n動かし\t動詞,自立,*,*,五段・サ行,連用形,動かす,ウゴカシ,ウゴカシ\n[dict2]found (['動かす', 'こと', 'が', 'できる'], 1, '経験')\n[dict2]found (['動かす', 'こと', 'は', 'できる'], 1, '経験')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['動かす', 'こと', 'が', 'できる'], 1, '経験')\n[dict2]found (['動かす', 'こと', 'は', 'できる'], 1, '経験')\n、\t記号,読点,*,*,*,*,、,、,、\nスッキリ\t副詞,助詞類接続,*,*,*,*,スッキリ,スッキリ,スッキリ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 雨上がりの虹を見て、心が洗われるようだった。\n\n雨上がり\t名詞,一般,*,*,*,*,雨上がり,アメアガリ,アメアガリ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n虹\t名詞,一般,*,*,*,*,虹,ニジ,ニジ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n見\t動詞,自立,*,*,一段,連用形,見る,ミ,ミ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\n、\t記号,読点,*,*,*,*,、,、,、\n心\t名詞,一般,*,*,*,*,心,ココロ,ココロ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\n洗わ\t動詞,自立,*,*,五段・ワ行促音便,未然形,洗う,アラワ,アラワ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\nれる\t動詞,接尾,*,*,一段,基本形,れる,レル,レル\nよう\t名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 試合に勝って、チーム全員で喜んだ。\n\n試合\t名詞,サ変接続,*,*,*,*,試合,シアイ,シアイ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n勝っ\t動詞,自立,*,*,五段・タ行,連用タ接続,勝つ,カッ,カッ\n[dict2]found (['勝つ'], 1, '経験')\n[dict2] ['勝つ']1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nチーム\t名詞,一般,*,*,*,*,チーム,チーム,チーム\n全員\t名詞,一般,*,*,*,*,全員,ゼンイン,ゼンイン\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n喜ん\t動詞,自立,*,*,五段・バ行,連用タ接続,喜ぶ,ヨロコン,ヨロコン\n[dict2]found (['喜ぶ'], 1, '経験')\n[dict2] ['喜ぶ']1\nだ\t助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n")
#
# (1, 'text: 今日は誕生日で、たくさんのメッセージをもらった。\n\n[dict1] 誕生 1\n[dict1] たくさん 0\n今日\t名詞,副詞可能,*,*,*,*,今日,キョウ,キョー\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n誕生\t名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー\n日\t名詞,接尾,一般,*,*,*,日,ビ,ビ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n、\t記号,読点,*,*,*,*,、,、,、\nたくさん\t名詞,副詞可能,*,*,*,*,たくさん,タクサン,タクサン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nメッセージ\t名詞,一般,*,*,*,*,メッセージ,メッセージ,メッセージ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nもらっ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (-3, "text: ミスをしてしまって、上司に怒られて落ち込んだ。\n\n[dict1] ミス -1\nミス\t名詞,サ変接続,*,*,*,*,ミス,ミス,ミス\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n上司\t名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n怒ら\t動詞,自立,*,*,五段・ラ行,未然形,怒る,オコラ,オコラ\n[dict2]found (['怒る'], -1, '経験')\n[dict2] ['怒る']-1\nれ\t動詞,接尾,*,*,一段,連用形,れる,レ,レ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n落ち込ん\t動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン\n[dict2]found (['落ち込む'], -1, '経験')\n[dict2] ['落ち込む']-1\nだ\t助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n")
#
# (0, "text: 久しぶりに母の手料理を食べて、懐かしい気分になった。\n\n[dict1] 久しぶり 0\n[dict1] 気分 0\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n母\t名詞,一般,*,*,*,*,母,ハハ,ハハ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n手料理\t名詞,一般,*,*,*,*,手料理,テリョウリ,テリョーリ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n食べ\t動詞,自立,*,*,一段,連用形,食べる,タベ,タベ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n懐かしい\t形容詞,自立,*,*,形容詞・イ段,基本形,懐かしい,ナツカシイ,ナツカシイ\n気分\t名詞,一般,*,*,*,*,気分,キブン,キブン\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n[dict2]found (['気分', 'が', '悪い'], -1, '評価')\n[dict2]found (['気分', 'が', 'いい'], 1, '評価')\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 面白い本を見つけて、読みふけってしまった。\n\n面白い\t形容詞,自立,*,*,形容詞・アウオ段,基本形,面白い,オモシロイ,オモシロイ\n[dict2]found (['面白い'], 1, '評価')\n[dict2] ['面白い']1\n本\t名詞,一般,*,*,*,*,本,ホン,ホン\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n見つけ\t動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n読みふけっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,読みふける,ヨミフケッ,ヨミフケッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 友達の結婚式に参加して、幸せな気持ちになった。\n\n[dict1] 友達 1\n[dict1] 参加 0\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n結婚式\t名詞,一般,*,*,*,*,結婚式,ケッコンシキ,ケッコンシキ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n参加\t名詞,サ変接続,*,*,*,*,参加,サンカ,サンカ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n幸せ\t名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, 'text: 風邪をひいてしまって、ずっと寝ている。\n\n[dict1] 風邪 -1\n風邪\t名詞,一般,*,*,*,*,風邪,カゼ,カゼ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nひい\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,ひく,ヒイ,ヒイ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nずっと\t副詞,一般,*,*,*,*,ずっと,ズット,ズット\n寝\t動詞,自立,*,*,一段,連用形,寝る,ネ,ネ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (0, 'text: 新しいゲームを始めて、ハマってしまった。\n\n[dict1] ゲーム 0\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\nゲーム\t名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n始め\t動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nハマっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (1, "text: 猫が膝の上に乗ってきて、癒された。\n\n猫\t名詞,一般,*,*,*,*,猫,ネコ,ネコ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\n膝\t名詞,一般,*,*,*,*,膝,ヒザ,ヒザ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n上\t名詞,非自立,副詞可能,*,*,*,上,ウエ,ウエ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n乗っ\t動詞,自立,*,*,五段・ラ行,連用タ接続,乗る,ノッ,ノッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nき\t動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n癒さ\t動詞,自立,*,*,五段・サ行,未然形,癒す,イヤサ,イヤサ\n[dict2]found (['癒す'], 1, '評価')\n[dict2] ['癒す']1\nれ\t動詞,接尾,*,*,一段,連用形,れる,レ,レ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 長い一日が終わって、ほっと一息ついた。\n\n長い\t形容詞,自立,*,*,形容詞・アウオ段,基本形,長い,ナガイ,ナガイ\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n日\t名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n終わっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nほっと\t副詞,一般,*,*,*,*,ほっと,ホット,ホット\n[dict2]found (['ほっと', 'する'], 1, '経験')\n一息\t名詞,一般,*,*,*,*,一息,ヒトイキ,ヒトイキ\n[dict2]found (['ほっと', 'する'], 1, '経験')\nつい\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 昇進が決まって、とても嬉しい。\n\n[dict1] 昇進 1\n昇進\t名詞,サ変接続,*,*,*,*,昇進,ショウシン,ショーシン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n決まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,決まる,キマッ,キマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n嬉しい\t形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: お風呂に入ってリラックスする時間が好き。\n\n[dict1] リラックス 1\n[dict1] 時間 0\n[dict1] 好き 1\nお\t接頭詞,名詞接続,*,*,*,*,お,オ,オ\n風呂\t名詞,一般,*,*,*,*,風呂,フロ,フロ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n入っ\t動詞,自立,*,*,五段・ラ行,連用タ接続,入る,ハイッ,ハイッ\n[dict2]found (['入る', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['入る', 'こと', 'は', 'できる'], 1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['入る', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['入る', 'こと', 'は', 'できる'], 1, '評価')\nリラックス\t名詞,サ変接続,*,*,*,*,リラックス,リラックス,リラックス\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n好き\t名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 友達とカフェでおしゃべりして、楽しい時間を過ごした。\n\n[dict1] 友達 1\n[dict1] 時間 0\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,並立助詞,*,*,*,*,と,ト,ト\nカフェ\t名詞,一般,*,*,*,*,カフェ,カフェ,カフェ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nおしゃべり\t名詞,サ変接続,*,*,*,*,おしゃべり,オシャベリ,オシャベリ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n楽しい\t形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n過ごし\t動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 自分の作品が認められて、嬉しい気持ちになった。\n\n[dict1] 自分 0\n[dict1] 気持ち 1\n自分\t名詞,一般,*,*,*,*,自分,ジブン,ジブン\n[dict2]found (['自分', '向き'], 1, '評価')\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n[dict2]found (['自分', '向き'], 1, '評価')\n作品\t名詞,一般,*,*,*,*,作品,サクヒン,サクヒン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n認め\t動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ\n[dict2]found (['認める'], 1, '評価')\n[dict2] ['認める']1\nられ\t動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n嬉しい\t形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 会議が長引いて疲れたけど、達成感がある。\n\n[dict1] 達成 1\n会議\t名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n長引い\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,長引く,ナガビイ,ナガビイ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n疲れ\t動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ\n[dict2]found (['疲れる'], -1, '経験')\n[dict2] ['疲れる']-1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\n、\t記号,読点,*,*,*,*,、,、,、\n達成\t名詞,サ変接続,*,*,*,*,達成,タッセイ,タッセイ\n感\t名詞,接尾,一般,*,*,*,感,カン,カン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nある\t動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル\n[dict2]found (['ある', 'がち', 'だ'], -1, '評価')\n[dict2]found (['ある', 'がち', 'です'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['ある', 'がち', 'だ'], -1, '評価')\n[dict2]found (['ある', 'がち', 'です'], -1, '評価')\n")
#
# (2, "text: 彼女との旅行が楽しみで、待ちきれない。\n\n[dict1] 旅行 1\n[dict1] 楽しみ 1\n彼女\t名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n旅行\t名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n楽しみ\t名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\n、\t記号,読点,*,*,*,*,、,、,、\n待ち\t動詞,自立,*,*,五段・タ行,連用形,待つ,マチ,マチ\nきれ\t動詞,非自立,*,*,一段,未然形,きれる,キレ,キレ\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, 'text: 仕事が終わって家に帰ると、ホッとする。\n\n[dict1] 仕事 0\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n終わっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n家\t名詞,一般,*,*,*,*,家,イエ,イエ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n帰る\t動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル\nと\t助詞,接続助詞,*,*,*,*,と,ト,ト\n、\t記号,読点,*,*,*,*,、,、,、\nホッ\t副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, "text: 好きなバンドのライブに行って、最高の夜だった。\n\n[dict1] 好き 1\n[dict1] 最高 1\n好き\t名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nバンド\t名詞,一般,*,*,*,*,バンド,バンド,バンド\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nライブ\t名詞,一般,*,*,*,*,ライブ,ライブ,ライブ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n行っ\t動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n最高\t名詞,一般,*,*,*,*,最高,サイコウ,サイコー\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n夜\t名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-2, "text: 忙しい日々が続いていて、少し疲れている。\n\n忙しい\t形容詞,自立,*,*,形容詞・イ段,基本形,忙しい,イソガシイ,イソガシイ\n[dict2]found (['忙しい'], -1, '評価')\n[dict2] ['忙しい']-1\n日々\t名詞,副詞可能,*,*,*,*,日々,ヒビ,ヒビ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n続い\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,続く,ツヅイ,ツズイ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nい\t動詞,非自立,*,*,一段,連用形,いる,イ,イ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n少し\t副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ\n疲れ\t動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ\n[dict2]found (['疲れる'], -1, '経験')\n[dict2] ['疲れる']-1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 彼氏からのサプライズに驚いて、嬉しかった。\n\n彼氏\t名詞,一般,*,*,*,*,彼氏,カレシ,カレシ\nから\t助詞,格助詞,一般,*,*,*,から,カラ,カラ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nサプライズ\t名詞,一般,*,*,*,*,サプライズ,*,*\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n驚い\t動詞,自立,*,*,五段・カ行イ音便,連用タ接続,驚く,オドロイ,オドロイ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n嬉しかっ\t形容詞,自立,*,*,形容詞・イ段,連用タ接続,嬉しい,ウレシカッ,ウレシカッ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 親友と大喧嘩してしまって、後悔している。\n\n[dict1] 親友 1\n[dict1] 喧嘩 -1\n[dict1] 後悔 -1\n親友\t名詞,一般,*,*,*,*,親友,シンユウ,シンユー\nと\t助詞,並立助詞,*,*,*,*,と,ト,ト\n大\t接頭詞,名詞接続,*,*,*,*,大,ダイ,ダイ\n[dict2]found (['大', 'それ', 'た'], -1, '評価')\n[dict2]found (['大', '満足'], 1, '評価')\n喧嘩\t名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ\n[dict2]found (['大', 'それ', 'た'], -1, '評価')\n[dict2]found (['大', '満足'], 1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n後悔\t名詞,サ変接続,*,*,*,*,後悔,コウカイ,コーカイ\n[dict2]found (['後悔', '先', 'に', '立た', 'ぬ'], -1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\n[dict2]found (['後悔', '先', 'に', '立た', 'ぬ'], -1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 美味しいラーメンを食べて、幸せな気持ちになった。\n\n[dict1] 幸せ 1\n[dict1] 気持ち 1\n美味しい\t形容詞,自立,*,*,形容詞・イ段,基本形,美味しい,オイシイ,オイシイ\n[dict2]found (['美味しい'], 1, '評価')\n[dict2] ['美味しい']1\nラーメン\t名詞,一般,*,*,*,*,ラーメン,ラーメン,ラーメン\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n食べ\t動詞,自立,*,*,一段,連用形,食べる,タベ,タベ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n幸せ\t名詞,形容動詞語幹,*,*,*,*,幸せ,シアワセ,シアワセ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, "text: 風が強くて、外に出るのが億劫だった。\n\n風\t名詞,一般,*,*,*,*,風,カゼ,カゼ\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'だ'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'です'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'と'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'の'], -1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'だ'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'です'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'と'], -1, '評価')\n[dict2]found (['風', 'の', '前', 'の', 'ちり', 'の'], -1, '評価')\n強く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,強い,ツヨク,ツヨク\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n外\t名詞,一般,*,*,*,*,外,ソト,ソト\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n出る\t動詞,自立,*,*,一段,基本形,出る,デル,デル\nの\t名詞,非自立,一般,*,*,*,の,ノ,ノ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n億劫\t名詞,形容動詞語幹,*,*,*,*,億劫,オックウ,オックー\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, 'text: 新しいプロジェクトが始まって、やる気満々。\n\n[dict1] やる気 1\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\nプロジェクト\t名詞,一般,*,*,*,*,プロジェクト,プロジェクト,プロジェクト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n始まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nやる気\t名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ\n満々\t名詞,一般,*,*,*,*,満々,マンマン,マンマン\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (-1, "text: 長時間の会議で疲れ果ててしまった。\n\n[dict1] 長時間 0\n長時間\t名詞,副詞可能,*,*,*,*,長時間,チョウジカン,チョージカン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n会議\t名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n疲れ\t動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ\n[dict2]found (['疲れる'], -1, '経験')\n[dict2] ['疲れる']-1\n果て\t動詞,自立,*,*,一段,連用形,果てる,ハテ,ハテ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 久しぶりに海に行って、リフレッシュできた。\n\n[dict1] 久しぶり 0\n[dict1] リフレッシュ 1\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n海\t名詞,一般,*,*,*,*,海,ウミ,ウミ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n行っ\t動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nリフレッシュ\t名詞,サ変接続,*,*,*,*,リフレッシュ,リフレッシュ,リフレッシュ\nでき\t動詞,自立,*,*,一段,連用形,できる,デキ,デキ\n[dict2]found (['できる', '損なう'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['できる', '損なう'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-3, "text: 試験勉強が大変で、ストレスが溜まっている。\n\n[dict1] 試験 -1\n[dict1] 大変 -1\n[dict1] ストレス -1\n試験\t名詞,サ変接続,*,*,*,*,試験,シケン,シケン\n勉強\t名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n大変\t名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン\nで\t助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n、\t記号,読点,*,*,*,*,、,、,、\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nストレス\t名詞,一般,*,*,*,*,ストレス,ストレス,ストレス\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\n溜まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,溜まる,タマッ,タマッ\n[dict2]found (['ストレス', 'が', 'ある'], -1, '経験')\n[dict2]found (['ストレス', 'が', 'ない'], 1, '経験')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 友達の赤ちゃんが生まれて、とても嬉しい。\n\n[dict1] 友達 1\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n赤ちゃん\t名詞,一般,*,*,*,*,赤ちゃん,アカチャン,アカチャン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n生まれ\t動詞,自立,*,*,一段,連用形,生まれる,ウマレ,ウマレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n嬉しい\t形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: プレゼントをもらって、心が温まった。\n\n[dict1] プレゼント 1\nプレゼント\t名詞,サ変接続,*,*,*,*,プレゼント,プレゼント,プレゼント\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nもらっ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n心\t名詞,一般,*,*,*,*,心,ココロ,ココロ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\n温まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,温まる,アタタマッ,アタタマッ\n[dict2]found (['心', 'が', '重い'], -1, '評価')\n[dict2]found (['心', 'が', '騒ぐ'], -1, '評価')\n[dict2]found (['心', 'を', '乱す'], -1, '評価')\n[dict2]found (['心', 'ある'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 好きなアーティストのコンサートが楽しみ。\n\n[dict1] 好き 1\n[dict1] アーティスト 0\n[dict1] 楽しみ 1\n好き\t名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nアーティスト\t名詞,一般,*,*,*,*,アーティスト,アーティスト,アーティスト\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nコンサート\t名詞,一般,*,*,*,*,コンサート,コンサート,コンサート\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n楽しみ\t名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\n")
#
# (0, 'text: 雨の日は読書に限ると、改めて感じた。\n\n[dict1] 雨 0\n雨\t名詞,一般,*,*,*,*,雨,アメ,アメ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n日\t名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n読書\t名詞,サ変接続,*,*,*,*,読書,ドクショ,ドクショ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n限る\t動詞,自立,*,*,五段・ラ行,基本形,限る,カギル,カギル\nと\t助詞,接続助詞,*,*,*,*,と,ト,ト\n、\t記号,読点,*,*,*,*,、,、,、\n改めて\t副詞,一般,*,*,*,*,改めて,アラタメテ,アラタメテ\n感じ\t動詞,自立,*,*,一段,連用形,感じる,カンジ,カンジ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (0, "text: 体調が良くなくて、会社を休んだ。\n\n体調\t名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n良く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク\n[dict2]found (['良い', 'ない'], -1, '評価')\n[dict2]found (['良い'], 1, '評価')\n[dict2] ['良い']1\nなく\t助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク\n[dict2]found (['良い', 'ない'], -1, '評価')\n[dict2] ['良い', 'ない']-1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n会社\t名詞,一般,*,*,*,*,会社,カイシャ,カイシャ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n休ん\t動詞,自立,*,*,五段・マ行,連用タ接続,休む,ヤスン,ヤスン\nだ\t助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n")
#
# (1, "text: 新しい料理に挑戦して、上手くできた。\n\n[dict1] 料理 0\n[dict1] 挑戦 0\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\n料理\t名詞,サ変接続,*,*,*,*,料理,リョウリ,リョーリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n挑戦\t名詞,サ変接続,*,*,*,*,挑戦,チョウセン,チョーセン\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n上手く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,上手い,ウマク,ウマク\n[dict2]found (['上手い'], 1, '評価')\n[dict2] ['上手い']1\nでき\t動詞,自立,*,*,一段,連用形,できる,デキ,デキ\n[dict2]found (['できる', '損なう'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['できる', '損なう'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 映画館で見た映画がとても面白かった。\n\n映画\t名詞,一般,*,*,*,*,映画,エイガ,エイガ\n館\t名詞,接尾,一般,*,*,*,館,カン,カン\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n見\t動詞,自立,*,*,一段,連用形,見る,ミ,ミ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')\n[dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')\n映画\t名詞,一般,*,*,*,*,映画,エイガ,エイガ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n面白かっ\t形容詞,自立,*,*,形容詞・アウオ段,連用タ接続,面白い,オモシロカッ,オモシロカッ\n[dict2]found (['面白い'], 1, '評価')\n[dict2] ['面白い']1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 彼氏とケンカして、悲しい気持ちになった。\n\n[dict1] ケンカ -1\n[dict1] 気持ち 1\n彼氏\t名詞,一般,*,*,*,*,彼氏,カレシ,カレシ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nケンカ\t名詞,サ変接続,*,*,*,*,ケンカ,ケンカ,ケンカ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n悲しい\t形容詞,自立,*,*,形容詞・イ段,基本形,悲しい,カナシイ,カナシイ\n[dict2]found (['悲しい'], -1, '評価')\n[dict2] ['悲しい']-1\n気持ち\t名詞,一般,*,*,*,*,気持ち,キモチ,キモチ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n[dict2]found (['気持ち', 'が', '悪い'], -1, '経験')\n[dict2]found (['気持ち', '悪い'], -1, '経験')\n[dict2]found (['気持ち', 'が', 'いい'], 1, '経験')\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 友達とアウトドアに出かけて、楽しかった。\n\n[dict1] 友達 1\n[dict1] アウトドア 0\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,並立助詞,*,*,*,*,と,ト,ト\nアウトドア\t名詞,一般,*,*,*,*,アウトドア,アウトドア,アウトドア\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n出かけ\t動詞,自立,*,*,一段,連用形,出かける,デカケ,デカケ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n楽しかっ\t形容詞,自立,*,*,形容詞・イ段,連用タ接続,楽しい,タノシカッ,タノシカッ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 上司に認められて、やる気が出た。\n\n[dict1] やる気 1\n上司\t名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n認め\t動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ\n[dict2]found (['認める'], 1, '評価')\n[dict2] ['認める']1\nられ\t動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nやる気\t名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (3, "text: 誕生日プレゼントをもらって、とても嬉しかった。\n\n[dict1] 誕生 1\n[dict1] プレゼント 1\n誕生\t名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー\n日\t名詞,接尾,一般,*,*,*,日,ビ,ビ\nプレゼント\t名詞,サ変接続,*,*,*,*,プレゼント,プレゼント,プレゼント\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nもらっ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n嬉しかっ\t形容詞,自立,*,*,形容詞・イ段,連用タ接続,嬉しい,ウレシカッ,ウレシカッ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 雪が降っていて、外に出るのが楽しみ。\n\n[dict1] 雪 0\n[dict1] 楽しみ 1\n雪\t名詞,一般,*,*,*,*,雪,ユキ,ユキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n降っ\t動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nい\t動詞,非自立,*,*,一段,連用形,いる,イ,イ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n外\t名詞,一般,*,*,*,*,外,ソト,ソト\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n出る\t動詞,自立,*,*,一段,基本形,出る,デル,デル\nの\t名詞,非自立,一般,*,*,*,の,ノ,ノ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n楽しみ\t名詞,一般,*,*,*,*,楽しみ,タノシミ,タノシミ\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['楽しみ', 'が', 'ない'], -1, '評価')\n")
#
# (1, 'text: 新しいカフェを見つけて、友達と行ってみた。\n\n[dict1] 友達 1\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\nカフェ\t名詞,一般,*,*,*,*,カフェ,カフェ,カフェ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n見つけ\t動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\n行っ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nみ\t動詞,非自立,*,*,一段,連用形,みる,ミ,ミ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (-2, "text: 仕事でミスしてしまって、落ち込んでいる。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nミス\t名詞,サ変接続,*,*,*,*,ミス,ミス,ミス\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n落ち込ん\t動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン\n[dict2]found (['落ち込む'], -1, '経験')\n[dict2] ['落ち込む']-1\nで\t助詞,接続助詞,*,*,*,*,で,デ,デ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 好きなアニメの新作が出て、ワクワクしている。\n\n[dict1] 好き 1\n[dict1] 新作 0\n好き\t名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nアニメ\t名詞,一般,*,*,*,*,アニメ,アニメ,アニメ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n新作\t名詞,サ変接続,*,*,*,*,新作,シンサク,シンサク\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nワクワク\t副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-2, "text: 体調が悪くて、早退した。\n\n[dict1] 早退 -1\n体調\t名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n悪く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク\n[dict2]found (['悪い'], -1, '評価')\n[dict2] ['悪い']-1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n早退\t名詞,サ変接続,*,*,*,*,早退,ソウタイ,ソータイ\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# ...
#
# (-1, 'text: ペットが病気になって心配でたまらない。早く元気になって。\n\n[dict1] ペット 0\n[dict1] 病気 -1\n[dict1] 心配 -1\n[dict1] 元気 1\nペット\t名詞,一般,*,*,*,*,ペット,ペット,ペット\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n病気\t名詞,サ変接続,*,*,*,*,病気,ビョウキ,ビョーキ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n心配\t名詞,サ変接続,*,*,*,*,心配,シンパイ,シンパイ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nたまらない\t形容詞,自立,*,*,形容詞・アウオ段,基本形,たまらない,タマラナイ,タマラナイ\n。\t記号,句点,*,*,*,*,。,。,。\n早く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク\n元気\t名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (-2, "text: 仕事でミスしてしまって、落ち込んでいる。\n\n[dict1] 仕事 0\n[dict1] ミス -1\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\nミス\t名詞,サ変接続,*,*,*,*,ミス,ミス,ミス\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\n[dict2]found (['ミス', 'マッチ'], -1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n落ち込ん\t動詞,自立,*,*,五段・マ行,連用タ接続,落ち込む,オチコン,オチコン\n[dict2]found (['落ち込む'], -1, '経験')\n[dict2] ['落ち込む']-1\nで\t助詞,接続助詞,*,*,*,*,で,デ,デ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 彼氏とのデートで、素敵な時間を過ごした。\n\n[dict1] デート 1\n[dict1] 素敵 1\n[dict1] 時間 0\n彼氏\t名詞,一般,*,*,*,*,彼氏,カレシ,カレシ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nデート\t名詞,サ変接続,*,*,*,*,デート,デート,デート\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n、\t記号,読点,*,*,*,*,、,、,、\n素敵\t名詞,形容動詞語幹,*,*,*,*,素敵,ステキ,ステキ\nな\t助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n過ごし\t動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 猫が膝の上に乗ってきて、癒された。\n\n猫\t名詞,一般,*,*,*,*,猫,ネコ,ネコ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\n膝\t名詞,一般,*,*,*,*,膝,ヒザ,ヒザ\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n上\t名詞,非自立,副詞可能,*,*,*,上,ウエ,ウエ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n乗っ\t動詞,自立,*,*,五段・ラ行,連用タ接続,乗る,ノッ,ノッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nき\t動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n癒さ\t動詞,自立,*,*,五段・サ行,未然形,癒す,イヤサ,イヤサ\n[dict2]found (['癒す'], 1, '評価')\n[dict2] ['癒す']1\nれ\t動詞,接尾,*,*,一段,連用形,れる,レ,レ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 友達とショッピングして、楽しい時間を過ごした。\n\n[dict1] 友達 1\n[dict1] 時間 0\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nショッピング\t名詞,サ変接続,*,*,*,*,ショッピング,ショッピング,ショッピング\nし\t動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\n楽しい\t形容詞,自立,*,*,形容詞・イ段,基本形,楽しい,タノシイ,タノシイ\n[dict2]found (['楽しい'], 1, '経験')\n[dict2] ['楽しい']1\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n過ごし\t動詞,自立,*,*,五段・サ行,連用形,過ごす,スゴシ,スゴシ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# [dict1]  プレゼント 1
# [dict2]  ['温まる'] 1
# 2
#
# (2, "text: 上司に認められて、やる気が出た。\n\n[dict1] やる気 1\n上司\t名詞,一般,*,*,*,*,上司,ジョウシ,ジョーシ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n認め\t動詞,自立,*,*,一段,未然形,認める,ミトメ,ミトメ\n[dict2]found (['認める'], 1, '評価')\n[dict2] ['認める']1\nられ\t動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nやる気\t名詞,一般,*,*,*,*,やる気,ヤルキ,ヤルキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, "text: 新しいレシピを試してみたら、美味しくできた。\n\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\nレシピ\t名詞,一般,*,*,*,*,レシピ,レシピ,レシピ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n試し\t動詞,自立,*,*,五段・サ行,連用形,試す,タメシ,タメシ\n[dict2]found (['試す', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['試す', 'こと', 'は', 'できる'], 1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['試す', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['試す', 'こと', 'は', 'できる'], 1, '評価')\nみ\t動詞,非自立,*,*,一段,連用形,みる,ミ,ミ\nたら\t助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ\n、\t記号,読点,*,*,*,*,、,、,、\n美味しく\t形容詞,自立,*,*,形容詞・イ段,連用テ接続,美味しい,オイシク,オイシク\n[dict2]found (['美味しい'], 1, '評価')\n[dict2] ['美味しい']1\nでき\t動詞,自立,*,*,一段,連用形,できる,デキ,デキ\n[dict2]found (['できる', '損なう'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['できる', '損なう'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 久しぶりに会った友達と話して、元気が出た。\n\n[dict1] 久しぶり 0\n[dict1] 友達 1\n[dict1] 元気 1\n久しぶり\t名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n会っ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,会う,アッ,アッ\n[dict2]found (['会う', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['会う', 'こと', 'は', 'できる'], 1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['会う', 'こと', 'が', 'できる'], 1, '評価')\n[dict2]found (['会う', 'こと', 'は', 'できる'], 1, '評価')\n友達\t名詞,一般,*,*,*,*,友達,トモダチ,トモダチ\nと\t助詞,格助詞,引用,*,*,*,と,ト,ト\n話し\t動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ\n[dict2]found (['話す', '上手', 'だ'], 1, '評価')\n[dict2]found (['話す', '上手', 'です'], 1, '評価')\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n[dict2]found (['話す', '上手', 'だ'], 1, '評価')\n[dict2]found (['話す', '上手', 'です'], 1, '評価')\n、\t記号,読点,*,*,*,*,、,、,、\n元気\t名詞,形容動詞語幹,*,*,*,*,元気,ゲンキ,ゲンキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n出\t動詞,自立,*,*,一段,連用形,出る,デ,デ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (2, "text: 昇進が決まって、とても嬉しい。\n\n[dict1] 昇進 1\n昇進\t名詞,サ変接続,*,*,*,*,昇進,ショウシン,ショーシン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n決まっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,決まる,キマッ,キマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nとても\t副詞,助詞類接続,*,*,*,*,とても,トテモ,トテモ\n嬉しい\t形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ\n[dict2]found (['嬉しい'], 1, '評価')\n[dict2] ['嬉しい']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, 'text: 仕事が終わって家に帰ると、ホッとする。\n\n[dict1] 仕事 0\n仕事\t名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n終わっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n家\t名詞,一般,*,*,*,*,家,イエ,イエ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n帰る\t動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル\nと\t助詞,接続助詞,*,*,*,*,と,ト,ト\n、\t記号,読点,*,*,*,*,、,、,、\nホッ\t副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# [dict2]  ['良い'] 1
# 1
#
# (-1, "text: 長時間の会議で疲れ果ててしまった。\n\n[dict1] 長時間 0\n長時間\t名詞,副詞可能,*,*,*,*,長時間,チョウジカン,チョージカン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n会議\t名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n疲れ\t動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ\n[dict2]found (['疲れる'], -1, '経験')\n[dict2] ['疲れる']-1\n果て\t動詞,自立,*,*,一段,連用形,果てる,ハテ,ハテ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (1, 'text: 今日は誕生日で、たくさんのメッセージをもらった。\n\n[dict1] 誕生 1\n[dict1] たくさん 0\n今日\t名詞,副詞可能,*,*,*,*,今日,キョウ,キョー\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n誕生\t名詞,サ変接続,*,*,*,*,誕生,タンジョウ,タンジョー\n日\t名詞,接尾,一般,*,*,*,日,ビ,ビ\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n、\t記号,読点,*,*,*,*,、,、,、\nたくさん\t名詞,副詞可能,*,*,*,*,たくさん,タクサン,タクサン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\nメッセージ\t名詞,一般,*,*,*,*,メッセージ,メッセージ,メッセージ\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nもらっ\t動詞,自立,*,*,五段・ワ行促音便,連用タ接続,もらう,モラッ,モラッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, 'text: 旅行の計画を立てているときが一番ワクワクする。\n\n[dict1] 旅行 1\n[dict1] 一番 1\n旅行\t名詞,サ変接続,*,*,*,*,旅行,リョコウ,リョコー\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n計画\t名詞,サ変接続,*,*,*,*,計画,ケイカク,ケイカク\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n立て\t動詞,自立,*,*,一段,連用形,立てる,タテ,タテ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nいる\t動詞,非自立,*,*,一段,基本形,いる,イル,イル\nとき\t名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n一番\t名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン\nワクワク\t副詞,助詞類接続,*,*,*,*,ワクワク,ワクワク,ワクワク\nする\t動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# (2, "text: 試合に勝って、チーム全員で喜んだ。\n\n試合\t名詞,サ変接続,*,*,*,*,試合,シアイ,シアイ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n勝っ\t動詞,自立,*,*,五段・タ行,連用タ接続,勝つ,カッ,カッ\n[dict2]found (['勝つ'], 1, '経験')\n[dict2] ['勝つ']1\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nチーム\t名詞,一般,*,*,*,*,チーム,チーム,チーム\n全員\t名詞,一般,*,*,*,*,全員,ゼンイン,ゼンイン\nで\t助詞,格助詞,一般,*,*,*,で,デ,デ\n喜ん\t動詞,自立,*,*,五段・バ行,連用タ接続,喜ぶ,ヨロコン,ヨロコン\n[dict2]found (['喜ぶ'], 1, '経験')\n[dict2] ['喜ぶ']1\nだ\t助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n。\t記号,句点,*,*,*,*,。,。,。\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\n")
#
# (3, "text: 猫と一緒に過ごす時間が一番の癒し。\n\n[dict1] 一緒 1\n[dict1] 時間 0\n[dict1] 一番 1\n猫\t名詞,一般,*,*,*,*,猫,ネコ,ネコ\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\nと\t助詞,格助詞,一般,*,*,*,と,ト,ト\n[dict2]found (['猫', 'に', '小判', 'だ'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'です'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'と'], -1, '評価')\n[dict2]found (['猫', 'に', '小判', 'の'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'だ'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'です'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'と'], -1, '評価')\n[dict2]found (['猫', 'の', '額', 'の'], -1, '評価')\n一緒\t名詞,サ変接続,*,*,*,*,一緒,イッショ,イッショ\nに\t助詞,格助詞,一般,*,*,*,に,ニ,ニ\n過ごす\t動詞,自立,*,*,五段・サ行,基本形,過ごす,スゴス,スゴス\n時間\t名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン\nが\t助詞,格助詞,一般,*,*,*,が,ガ,ガ\n一番\t名詞,副詞可能,*,*,*,*,一番,イチバン,イチバン\nの\t助詞,連体化,*,*,*,*,の,ノ,ノ\n癒し\t動詞,自立,*,*,五段・サ行,連用形,癒す,イヤシ,イヤシ\n[dict2]found (['癒す'], 1, '評価')\n[dict2] ['癒す']1\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (-1, "text: 今日は特に何もない一日だったけど、それも悪くない。\n\n今日\t名詞,副詞可能,*,*,*,*,今日,キョウ,キョー\nは\t助詞,係助詞,*,*,*,*,は,ハ,ワ\n特に\t副詞,一般,*,*,*,*,特に,トクニ,トクニ\n何\t名詞,代名詞,一般,*,*,*,何,ナニ,ナニ\n[dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')\n[dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\n[dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')\n[dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')\nない\t形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ\n一\t名詞,数,*,*,*,*,一,イチ,イチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\n日\t名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ\n[dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')\n[dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')\nだっ\t助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n[dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')\nけど\t助詞,接続助詞,*,*,*,*,けど,ケド,ケド\n、\t記号,読点,*,*,*,*,、,、,、\nそれ\t名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ\nも\t助詞,係助詞,*,*,*,*,も,モ,モ\n悪く\t形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク\n[dict2]found (['悪い'], -1, '評価')\n[dict2] ['悪い']-1\nない\t助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\n。\t記号,句点,*,*,*,*,。,。,。\n")
#
# (0, 'text: 新しいゲームを始めて、ハマってしまった。\n\n[dict1] ゲーム 0\n新しい\t形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ\nゲーム\t名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム\nを\t助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n始め\t動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\n、\t記号,読点,*,*,*,*,、,、,、\nハマっ\t動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ\nて\t助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ\t動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nた\t助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n。\t記号,句点,*,*,*,*,。,。,。\n')
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# 2
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# 3
#
# text: 雪が降っていて、外に出るのが楽しみ。
#
# [dict1]  雪 0
# [dict1]  楽しみ 1
# 1
#
# text: 新しいカフェを見つけて、友達と行ってみた。
#
# [dict1]  友達 1
# 1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# -2
#
# text: 好きなアニメの新作が出て、ワクワクしている。
#
# [dict1]  好き 1
# [dict1]  新作 0
# [dict2]  ['わくわく'] 1
# 2
#
# text: 体調が悪くて、早退した。
#
# [dict1]  早退 -1
# [dict2]  ['悪い'] -1
# -2
#
# text: 友達と旅行に行って、最高の思い出ができた。
#
# [dict1]  友達 1
# [dict1]  旅行 1
# [dict1]  最高 1
# [dict1]  思い出 1
# 4
#
# text: 疲れているのに、寝付けない夜が続いている。
#
# [dict2]  ['疲れる'] -1
# -1
#
# text: 新しい靴を買って、ウキウキしている。
#
# [dict2]  ['うきうき'] 1
# 1
#
# text: 恋人との記念日を祝って、幸せな時間を過ごした。
#
# [dict1]  恋人 1
# [dict1]  記念 0
# [dict1]  幸せ 1
# [dict1]  時間 0
# 2
#
# text: 上司に褒められて、自信がついた。
#
# [dict1]  自信 1
# 1
#
# text: 雨の日の静けさが好きで、落ち着く。
#
# [dict1]  雨 0
# [dict1]  静けさ 1
# [dict1]  好き 1
# [dict2]  ['落ち着く'] 1
# 3
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# 2
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: お風呂にゆっくり浸かって、リラックスした。
#
# [dict1]  リラックス 1
# 1
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# -1
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 大好きなカフェで、ゆっくり過ごす時間が幸せ。
#
# [dict1]  大好き 1
# [dict1]  時間 0
# [dict1]  幸せ 1
# 2
#
# text: 友達の誕生日を祝って、一緒に楽しんだ。
#
# [dict1]  友達 1
# [dict1]  誕生 1
# [dict1]  一緒 1
# [dict2]  ['楽しむ'] 1
# 4
#
# text: 仕事が忙しくて、なかなか休めない。
#
# [dict1]  仕事 0
# [dict2]  ['忙しい'] -1
# -1
#
# text: 好きな映画を見て、リフレッシュできた。
#
# [dict1]  好き 1
# [dict1]  リフレッシュ 1
# 2
#
# text: 新しい趣味を見つけて、毎日が楽しい。
#
# [dict1]  趣味 0
# [dict2]  ['楽しい'] 1
# 1
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 雨が降っていて、外に出るのが憂鬱。
#
# [dict1]  雨 0
# [dict1]  憂鬱 -1
# -1
#
# text: 友達と一緒にいると、元気が出る。
#
# [dict1]  友達 1
# [dict1]  一緒 1
# [dict1]  元気 1
# 3
#
# text: 仕事でミスをして、上司に叱られた。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# -1
#
# text: 新しいレストランで、美味しい料理を楽しんだ。
#
# [dict1]  料理 0
# [dict2]  ['美味しい'] 1
# [dict2]  ['楽しむ'] 1
# 2
#
# text: 体調が悪くて、一日中寝ていた。
#
# [dict1]  中 0
# [dict2]  ['悪い'] -1
# -1
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 彼氏からのサプライズに感動した。
#
# [dict1]  感動 1
# 1
#
# text: 忙しい日々が続いていて、少し疲れている。
#
# [dict2]  ['忙しい'] -1
# [dict2]  ['疲れる'] -1
# -2
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# 3
#
# text: 雨の日はどうしても気分が沈んでしまう。
#
# [dict1]  雨 0
# [dict1]  気分 0
# 0
#
# text: 新しい仕事が始まって、緊張するけど頑張りたい。
#
# [dict1]  仕事 0
# [dict1]  緊張 -1
# [dict2]  ['頑張る'] 1
# 0
#
# text: 友達の赤ちゃんが生まれて、とても嬉しい。
#
# [dict1]  友達 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 彼氏との電話が楽しくて、夜更かししてしまった。
#
# [dict2]  ['楽しい'] 1
# 1
#
# text: 仕事で成果を出して、達成感がある。
#
# [dict1]  仕事 0
# [dict1]  成果 1
# [dict1]  達成 1
# 2
#
# text: 体調が良くなくて、会社を休んだ。
#
# [dict2]  ['良い'] 1
# 1
#
# text: 好きな音楽を聴くと気分が明るくなる。
#
# [dict1]  好き 1
# [dict1]  気分 0
# [dict2]  ['明るい'] 1
# 2
#
# text: 友達と映画を見に行ったけど、感動して泣いちゃった。
#
# [dict1]  友達 1
# [dict1]  感動 1
# 2
#
# text: 新しいプロジェクトが始まって、やる気満々。
#
# [dict1]  やる気 1
# 1
#
# text: 彼女との旅行が楽しみで、待ちきれない。
#
# [dict1]  旅行 1
# [dict1]  楽しみ 1
# 2
#
# text: 誕生日プレゼントをもらって、とても嬉しかった。
#
# [dict1]  誕生 1
# [dict1]  プレゼント 1
# [dict2]  ['嬉しい'] 1
# 3
#
# text: 好きなドラマの新シーズンが始まって嬉しい。
#
# [dict1]  好き 1
# [dict1]  新 0
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
#
# [dict1]  久しぶり 0
# [dict1]  休み 0
# 0
#
# text: 友達とのランチがとても楽しかった。
#
# [dict1]  友達 1
# [dict2]  ['楽しい'] 1
# 2
#
# text: 彼女と喧嘩して、気まずい雰囲気になった。
#
# [dict1]  喧嘩 -1
# [dict1]  雰囲気 1
# [dict2]  ['気まずい'] -1
# -1
#
# text: 新しい本を読み始めて、止まらなくなった。
#
# 0
#
# text: 仕事が忙しくてストレスが溜まっている。
#
# [dict1]  仕事 0
# [dict1]  ストレス -1
# [dict2]  ['忙しい'] -1
# -2
#
# text: ペットが病気になって心配でたまらない。早く元気になって。
#
# [dict1]  ペット 0
# [dict1]  病気 -1
# [dict1]  心配 -1
# [dict1]  元気 1
# -1
#
# text: 仕事でミスしてしまって、落ち込んでいる。
#
# [dict1]  仕事 0
# [dict1]  ミス -1
# [dict2]  ['落ち込む'] -1
# -2
#
# text: 彼氏とのデートで、素敵な時間を過ごした。
#
# [dict1]  デート 1
# [dict1]  素敵 1
# [dict1]  時間 0
# 2
#
# text: 猫が膝の上に乗ってきて、癒された。
#
# [dict2]  ['癒す'] 1
# 1
#
# text: 友達とショッピングして、楽しい時間を過ごした。
#
# [dict1]  友達 1
# [dict1]  時間 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 友達とアウトドアに出かけて、楽しかった。
#
# [dict1]  友達 1
# [dict1]  アウトドア 0
# [dict2]  ['楽しい'] 1
# 2
#
# text: 上司に認められて、やる気が出た。
#
# [dict1]  やる気 1
# [dict2]  ['認める'] 1
# 2
#
# text: 新しいレシピを試してみたら、美味しくできた。
#
# [dict2]  ['美味しい'] 1
# 1
#
# text: 久しぶりに会った友達と話して、元気が出た。
#
# [dict1]  久しぶり 0
# [dict1]  友達 1
# [dict1]  元気 1
# 2
#
# text: 昇進が決まって、とても嬉しい。
#
# [dict1]  昇進 1
# [dict2]  ['嬉しい'] 1
# 2
#
# text: 仕事が終わって家に帰ると、ホッとする。
#
# [dict1]  仕事 0
# 0
#
# text: 映画館で見た映画がとても面白かった。
#
# [dict2]  ['面白い'] 1
# 1
#
# text: 長時間の会議で疲れ果ててしまった。
#
# [dict1]  長時間 0
# [dict2]  ['疲れる'] -1
# -1
#
# text: 今日は誕生日で、たくさんのメッセージをもらった。
#
# [dict1]  誕生 1
# [dict1]  たくさん 0
# 1
#
# text: 旅行の計画を立てているときが一番ワクワクする。
#
# [dict1]  旅行 1
# [dict1]  一番 1
# [dict2]  ['わくわく'] 1
# 3
#
# text: 試合に勝って、チーム全員で喜んだ。
#
# [dict2]  ['勝つ'] 1
# [dict2]  ['喜ぶ'] 1
# 2
#
# text: 猫と一緒に過ごす時間が一番の癒し。
#
# [dict1]  一緒 1
# [dict1]  時間 0
# [dict1]  一番 1
# [dict2]  ['癒す'] 1
# 3
#
# text: 今日は特に何もない一日だったけど、それも悪くない。
#
# [dict2]  ['悪い'] -1
# -1
#
# text: 新しいゲームを始めて、ハマってしまった。
#
# [dict1]  ゲーム 0
# 0
#
# text: 友達の結婚式に参加して、幸せな気持ちになった。```
#
# [dict1]  友達 1
# [dict1]  参加 0
# [dict1]  幸せ 1
# [dict1]  気持ち 1
# 3

# %%
polar_estimator.estimate_v2("電車が遅れてイライラするけど、仕方がない。", verbose=True)
# Out:
# text: 電車が遅れてイライラするけど、仕方がない。
# [dict2]  ['遅れる'] -1
# [dict2]  ['仕方', 'が', 'ない'] -1
# -2

# %%
with open("../data/data_ans.txt", "r", encoding="UTF-8") as f:
    data_text_with_ans = f.readlines()
l_pol_and_text=[]
for l in data_text_with_ans:
    pol_and_text=l.split(" ")
    pol_and_text[1]=pol_and_text[1].replace("\n","")
    
    l_pol_and_text.append(pol_and_text)
def pol_to_sign(pol:str)->int:
    if(pol=="e"):
        return 0
    if(pol=="n"):
        return -1
    if(pol=="p"):
        return 1
    return None

# %%
count_diff = 0
for t in l_pol_and_text:
    score, text = polar_estimator.estimate_v2(t[1], verbose=True)
    pol_sign = pol_to_sign(t[0])
    success = True
    if(pol_sign==0):
        if(score!=0):
            success=False
    elif(int(pol_sign)*int(score)<=0):
        success=False
    if not success:
        count_diff+=1
        print("↓")
        print(t)
        print("======")
        print("evaluated score:",score,", ans:",pol_sign)
        print(text)
        print("↑")
print("sum of number  of diffs:",count_diff)
# Out:
# ↓
# ['n', '雨が降ってるから気分が落ち込む。早く晴れてほしいな。']
# ======
# evaluated score: 1 , ans: -1
# text: 雨が降ってるから気分が落ち込む。早く晴れてほしいな。
# [dict1] 雨 0
# [dict1] 気分 0
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# てる	動詞,非自立,*,*,一段,基本形,てる,テル,テル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 落ち込む	動詞,自立,*,*,五段・マ行,基本形,落ち込む,オチコム,オチコム
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# 晴れ	動詞,自立,*,*,一段,連用形,晴れる,ハレ,ハレ
# [dict2]found (['晴れる'], 1, '経験')
# [dict2] ['晴れる']1
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ほしい	形容詞,非自立,*,*,形容詞・イ段,基本形,ほしい,ホシイ,ホシイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい仕事が始まって緊張するけど、頑張りたい。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい仕事が始まって緊張するけど、頑張りたい。
# [dict1] 仕事 0
# [dict1] 緊張 -1
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 緊張	名詞,サ変接続,*,*,*,*,緊張,キンチョウ,キンチョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# 頑張り	動詞,自立,*,*,五段・ラ行,連用形,頑張る,ガンバリ,ガンバリ
# [dict2]found (['頑張る'], 1, '経験')
# [dict2] ['頑張る']1
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '今日も一日がんばった。自分を褒めたい気分。']
# ======
# evaluated score: 0 , ans: 1
# text: 今日も一日がんばった。自分を褒めたい気分。
# [dict1] 自分 0
# [dict1] 気分 0
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# がんばっ	動詞,自立,*,*,五段・ラ行,連用タ接続,がんばる,ガンバッ,ガンバッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# [dict2]found (['自分', '向き'], 1, '評価')
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# [dict2]found (['自分', '向き'], 1, '評価')
# 褒め	動詞,自立,*,*,一段,連用形,褒める,ホメ,ホメ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
#
# ↑
# ↓
# ['n', '雨の日はどうしても気分が沈んでしまう。']
# ======
# evaluated score: 0 , ans: -1
# text: 雨の日はどうしても気分が沈んでしまう。
# [dict1] 雨 0
# [dict1] 気分 0
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 日	名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どうしても	副詞,一般,*,*,*,*,どうしても,ドウシテモ,ドーシテモ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 沈ん	動詞,自立,*,*,五段・マ行,連用タ接続,沈む,シズン,シズン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# しまう	動詞,非自立,*,*,五段・ワ行促音便,基本形,しまう,シマウ,シマウ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '久しぶりに休みが取れて、ゆっくり休むことができた。']
# ======
# evaluated score: 0 , ans: 1
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
# [dict1] 久しぶり 0
# [dict1] 休み 0
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 休み	名詞,一般,*,*,*,*,休み,ヤスミ,ヤスミ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 取れ	動詞,自立,*,*,一段,連用形,取れる,トレ,トレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 休む	動詞,自立,*,*,五段・マ行,基本形,休む,ヤスム,ヤスム
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# [dict2]found (['できる', '損なう'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['できる', '損なう'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['n', '友達と喧嘩してしまって、悲しい気持ちになった。']
# ======
# evaluated score: 0 , ans: -1
# text: 友達と喧嘩してしまって、悲しい気持ちになった。
# [dict1] 友達 1
# [dict1] 喧嘩 -1
# [dict1] 気持ち 1
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 悲しい	形容詞,自立,*,*,形容詞・イ段,基本形,悲しい,カナシイ,カナシイ
# [dict2]found (['悲しい'], -1, '評価')
# [dict2] ['悲しい']-1
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# [dict2]found (['気持ち', 'が', '悪い'], -1, '経験')
# [dict2]found (['気持ち', '悪い'], -1, '経験')
# [dict2]found (['気持ち', 'が', 'いい'], 1, '経験')
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# [dict2]found (['気持ち', 'が', '悪い'], -1, '経験')
# [dict2]found (['気持ち', '悪い'], -1, '経験')
# [dict2]found (['気持ち', 'が', 'いい'], 1, '経験')
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい洋服を買って、気分が上がった。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい洋服を買って、気分が上がった。
# [dict1] 気分 0
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 洋服	名詞,一般,*,*,*,*,洋服,ヨウフク,ヨーフク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 上がっ	動詞,自立,*,*,五段・ラ行,連用タ接続,上がる,アガッ,アガッ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['e', '今日は特に何もない一日だったけど、それも悪くない。']
# ======
# evaluated score: -1 , ans: 0
# text: 今日は特に何もない一日だったけど、それも悪くない。
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 特に	副詞,一般,*,*,*,*,特に,トクニ,トクニ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# [dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')
# [dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# [dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')
# [dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# [dict2]found (['悪い'], -1, '評価')
# [dict2] ['悪い']-1
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', 'スポーツジムで体を動かして、スッキリした。']
# ======
# evaluated score: 0 , ans: 1
# text: スポーツジムで体を動かして、スッキリした。
# [dict1] スポーツ 0
# スポーツ	名詞,一般,*,*,*,*,スポーツ,スポーツ,スポーツ
# ジム	名詞,一般,*,*,*,*,ジム,ジム,ジム
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 体	名詞,一般,*,*,*,*,体,カラダ,カラダ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 動かし	動詞,自立,*,*,五段・サ行,連用形,動かす,ウゴカシ,ウゴカシ
# [dict2]found (['動かす', 'こと', 'が', 'できる'], 1, '経験')
# [dict2]found (['動かす', 'こと', 'は', 'できる'], 1, '経験')
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# [dict2]found (['動かす', 'こと', 'が', 'できる'], 1, '経験')
# [dict2]found (['動かす', 'こと', 'は', 'できる'], 1, '経験')
# 、	記号,読点,*,*,*,*,、,、,、
# スッキリ	副詞,助詞類接続,*,*,*,*,スッキリ,スッキリ,スッキリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '雨上がりの虹を見て、心が洗われるようだった。']
# ======
# evaluated score: 0 , ans: 1
# text: 雨上がりの虹を見て、心が洗われるようだった。
# 雨上がり	名詞,一般,*,*,*,*,雨上がり,アメアガリ,アメアガリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 虹	名詞,一般,*,*,*,*,虹,ニジ,ニジ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# [dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')
# [dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# [dict2]found (['見る', 'かげ', 'も', 'ない'], -1, '評価')
# [dict2]found (['見る', '影', 'も', 'ない'], -1, '評価')
# 、	記号,読点,*,*,*,*,、,、,、
# 心	名詞,一般,*,*,*,*,心,ココロ,ココロ
# [dict2]found (['心', 'が', '重い'], -1, '評価')
# [dict2]found (['心', 'が', '騒ぐ'], -1, '評価')
# [dict2]found (['心', 'を', '乱す'], -1, '評価')
# [dict2]found (['心', 'ある'], 1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['心', 'が', '重い'], -1, '評価')
# [dict2]found (['心', 'が', '騒ぐ'], -1, '評価')
# [dict2]found (['心', 'を', '乱す'], -1, '評価')
# [dict2]found (['心', 'ある'], 1, '評価')
# 洗わ	動詞,自立,*,*,五段・ワ行促音便,未然形,洗う,アラワ,アラワ
# [dict2]found (['心', 'が', '重い'], -1, '評価')
# [dict2]found (['心', 'が', '騒ぐ'], -1, '評価')
# [dict2]found (['心', 'を', '乱す'], -1, '評価')
# [dict2]found (['心', 'ある'], 1, '評価')
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '久しぶりに母の手料理を食べて、懐かしい気分になった。']
# ======
# evaluated score: 0 , ans: 1
# text: 久しぶりに母の手料理を食べて、懐かしい気分になった。
# [dict1] 久しぶり 0
# [dict1] 気分 0
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 母	名詞,一般,*,*,*,*,母,ハハ,ハハ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 手料理	名詞,一般,*,*,*,*,手料理,テリョウリ,テリョーリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 食べ	動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 懐かしい	形容詞,自立,*,*,形容詞・イ段,基本形,懐かしい,ナツカシイ,ナツカシイ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しいゲームを始めて、ハマってしまった。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しいゲームを始めて、ハマってしまった。
# [dict1] ゲーム 0
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ゲーム	名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 始め	動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ハマっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '長い一日が終わって、ほっと一息ついた。']
# ======
# evaluated score: 0 , ans: 1
# text: 長い一日が終わって、ほっと一息ついた。
# 長い	形容詞,自立,*,*,形容詞・アウオ段,基本形,長い,ナガイ,ナガイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ほっと	副詞,一般,*,*,*,*,ほっと,ホット,ホット
# [dict2]found (['ほっと', 'する'], 1, '経験')
# 一息	名詞,一般,*,*,*,*,一息,ヒトイキ,ヒトイキ
# [dict2]found (['ほっと', 'する'], 1, '経験')
# つい	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,つく,ツイ,ツイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '会議が長引いて疲れたけど、達成感がある。']
# ======
# evaluated score: 0 , ans: 1
# text: 会議が長引いて疲れたけど、達成感がある。
# [dict1] 達成 1
# 会議	名詞,サ変接続,*,*,*,*,会議,カイギ,カイギ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 長引い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,長引く,ナガビイ,ナガビイ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 疲れ	動詞,自立,*,*,一段,連用形,疲れる,ツカレ,ツカレ
# [dict2]found (['疲れる'], -1, '経験')
# [dict2] ['疲れる']-1
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# 達成	名詞,サ変接続,*,*,*,*,達成,タッセイ,タッセイ
# 感	名詞,接尾,一般,*,*,*,感,カン,カン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# [dict2]found (['ある', 'がち', 'だ'], -1, '評価')
# [dict2]found (['ある', 'がち', 'です'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
# [dict2]found (['ある', 'がち', 'だ'], -1, '評価')
# [dict2]found (['ある', 'がち', 'です'], -1, '評価')
#
# ↑
# ↓
# ['p', '仕事が終わって家に帰ると、ホッとする。']
# ======
# evaluated score: 0 , ans: 1
# text: 仕事が終わって家に帰ると、ホッとする。
# [dict1] 仕事 0
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 家	名詞,一般,*,*,*,*,家,イエ,イエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 帰る	動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# ホッ	副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['n', '風が強くて、外に出るのが億劫だった。']
# ======
# evaluated score: 0 , ans: -1
# text: 風が強くて、外に出るのが億劫だった。
# 風	名詞,一般,*,*,*,*,風,カゼ,カゼ
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'だ'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'です'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'と'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'の'], -1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'だ'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'です'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'と'], -1, '評価')
# [dict2]found (['風', 'の', '前', 'の', 'ちり', 'の'], -1, '評価')
# 強く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,強い,ツヨク,ツヨク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 外	名詞,一般,*,*,*,*,外,ソト,ソト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 出る	動詞,自立,*,*,一段,基本形,出る,デル,デル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 億劫	名詞,形容動詞語幹,*,*,*,*,億劫,オックウ,オックー
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['n', '体調が良くなくて、会社を休んだ。']
# ======
# evaluated score: 0 , ans: -1
# text: 体調が良くなくて、会社を休んだ。
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# [dict2]found (['良い', 'ない'], -1, '評価')
# [dict2]found (['良い'], 1, '評価')
# [dict2] ['良い']1
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# [dict2]found (['良い', 'ない'], -1, '評価')
# [dict2] ['良い', 'ない']-1
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 会社	名詞,一般,*,*,*,*,会社,カイシャ,カイシャ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 休ん	動詞,自立,*,*,五段・マ行,連用タ接続,休む,ヤスン,ヤスン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
#
# ↑
# ↓
# ['e', '新しいカフェを見つけて、友達と行ってみた。']
# ======
# evaluated score: 1 , ans: 0
# text: 新しいカフェを見つけて、友達と行ってみた。
# [dict1] 友達 1
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# カフェ	名詞,一般,*,*,*,*,カフェ,カフェ,カフェ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 友達	名詞,一般,*,*,*,*,友達,トモダチ,トモダチ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 行っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい靴を買って、ウキウキしている。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい靴を買って、ウキウキしている。
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 靴	名詞,一般,*,*,*,*,靴,クツ,クツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 買っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,買う,カッ,カッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ウキウキ	副詞,一般,*,*,*,*,ウキウキ,ウキウキ,ウキウキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい本を読み始めて、止まらなくなった。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい本を読み始めて、止まらなくなった。
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 読み	動詞,自立,*,*,五段・マ行,連用形,読む,ヨミ,ヨミ
# 始め	動詞,非自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 止まら	動詞,自立,*,*,五段・ラ行,未然形,止まる,トマラ,トマラ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['n', '雨の日はどうしても気分が沈んでしまう。']
# ======
# evaluated score: 0 , ans: -1
# text: 雨の日はどうしても気分が沈んでしまう。
# [dict1] 雨 0
# [dict1] 気分 0
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 日	名詞,非自立,副詞可能,*,*,*,日,ヒ,ヒ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どうしても	副詞,一般,*,*,*,*,どうしても,ドウシテモ,ドーシテモ
# 気分	名詞,一般,*,*,*,*,気分,キブン,キブン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# 沈ん	動詞,自立,*,*,五段・マ行,連用タ接続,沈む,シズン,シズン
# [dict2]found (['気分', 'が', '悪い'], -1, '評価')
# [dict2]found (['気分', 'が', 'いい'], 1, '評価')
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# しまう	動詞,非自立,*,*,五段・ワ行促音便,基本形,しまう,シマウ,シマウ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい仕事が始まって、緊張するけど頑張りたい。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい仕事が始まって、緊張するけど頑張りたい。
# [dict1] 仕事 0
# [dict1] 緊張 -1
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まっ	動詞,自立,*,*,五段・ラ行,連用タ接続,始まる,ハジマッ,ハジマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 緊張	名詞,サ変接続,*,*,*,*,緊張,キンチョウ,キンチョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 頑張り	動詞,自立,*,*,五段・ラ行,連用形,頑張る,ガンバリ,ガンバリ
# [dict2]found (['頑張る'], 1, '経験')
# [dict2] ['頑張る']1
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['n', '体調が良くなくて、会社を休んだ。']
# ======
# evaluated score: 0 , ans: -1
# text: 体調が良くなくて、会社を休んだ。
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# [dict2]found (['良い', 'ない'], -1, '評価')
# [dict2]found (['良い'], 1, '評価')
# [dict2] ['良い']1
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# [dict2]found (['良い', 'ない'], -1, '評価')
# [dict2] ['良い', 'ない']-1
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 会社	名詞,一般,*,*,*,*,会社,カイシャ,カイシャ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 休ん	動詞,自立,*,*,五段・マ行,連用タ接続,休む,ヤスン,ヤスン
# だ	助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
#
# ↑
# ↓
# ['p', '久しぶりに休みが取れて、ゆっくり休むことができた。']
# ======
# evaluated score: 0 , ans: 1
# text: 久しぶりに休みが取れて、ゆっくり休むことができた。
# [dict1] 久しぶり 0
# [dict1] 休み 0
# 久しぶり	名詞,一般,*,*,*,*,久しぶり,ヒサシブリ,ヒサシブリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 休み	名詞,一般,*,*,*,*,休み,ヤスミ,ヤスミ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 取れ	動詞,自立,*,*,一段,連用形,取れる,トレ,トレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ゆっくり	副詞,助詞類接続,*,*,*,*,ゆっくり,ユックリ,ユックリ
# 休む	動詞,自立,*,*,五段・マ行,基本形,休む,ヤスム,ヤスム
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# [dict2]found (['できる', '損なう'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['できる', '損なう'], -1, '評価')
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しい本を読み始めて、止まらなくなった。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しい本を読み始めて、止まらなくなった。
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 本	名詞,一般,*,*,*,*,本,ホン,ホン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 読み	動詞,自立,*,*,五段・マ行,連用形,読む,ヨミ,ヨミ
# 始め	動詞,非自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# 止まら	動詞,自立,*,*,五段・ラ行,未然形,止まる,トマラ,トマラ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '仕事が終わって家に帰ると、ホッとする。']
# ======
# evaluated score: 0 , ans: 1
# text: 仕事が終わって家に帰ると、ホッとする。
# [dict1] 仕事 0
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 終わっ	動詞,自立,*,*,五段・ラ行,連用タ接続,終わる,オワッ,オワッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 家	名詞,一般,*,*,*,*,家,イエ,イエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 帰る	動詞,自立,*,*,五段・ラ行,基本形,帰る,カエル,カエル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# ホッ	副詞,助詞類接続,*,*,*,*,ホッ,ホッ,ホッ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['e', '今日は特に何もない一日だったけど、それも悪くない。']
# ======
# evaluated score: -1 , ans: 0
# text: 今日は特に何もない一日だったけど、それも悪くない。
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 特に	副詞,一般,*,*,*,*,特に,トクニ,トクニ
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# [dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')
# [dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# [dict2]found (['何', 'に', 'も', 'なら', 'ない'], -1, '評価')
# [dict2]found (['何', 'の', 'へんてつ', 'も', 'ない'], -1, '評価')
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# [dict2]found (['一', '卷', 'の', '終り', 'だ'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'です'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'と'], -1, '評価')
# [dict2]found (['一', '卷', 'の', '終り', 'の'], -1, '評価')
# だっ	助動詞,*,*,*,特殊・ダ,連用タ接続,だ,ダッ,ダッ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# [dict2]found (['だ', 'ら', 'ける', 'た'], -1, '評価')
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 悪く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,悪い,ワルク,ワルク
# [dict2]found (['悪い'], -1, '評価')
# [dict2] ['悪い']-1
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# ↓
# ['p', '新しいゲームを始めて、ハマってしまった。']
# ======
# evaluated score: 0 , ans: 1
# text: 新しいゲームを始めて、ハマってしまった。
# [dict1] ゲーム 0
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ゲーム	名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 始め	動詞,自立,*,*,一段,連用形,始める,ハジメ,ハジメ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ハマっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ハマる,ハマッ,ハマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# しまっ	動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
# ↑
# sum of number  of diffs: 28
